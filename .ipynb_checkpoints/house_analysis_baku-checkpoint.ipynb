# %%
from selenium import webdriver
#from BeautifulSoup import BeautifulSoup

from bs4 import BeautifulSoup
import pandas as pd
import requests

import datetime 
from datetime import datetime

# %%
URL = "https://bina.az/baki/alqi-satqi/menziller/yeni-tikili/2-otaqli?items_view=list"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
results = soup.find(id="js-items-search")

# %%
#print(results.prettify())

# %%
job_elements = results.find_all("div", class_="card_params")

# %%
#for job_element in job_elements:
   # print(job_element, end="\n"*2)

# %%
prices=[] #List to store name of the product
locations=[] #List to store price of the product
names=[] #List to store rating of the product
dates_posted=[] 


for job_element in job_elements:
    
    name = job_element.find("ul", class_="name")
    location = job_element.find(class_="location")
    price = job_element.find("span", class_="price-val")
    date_posted = job_element.find(class_="city_when")
    
    names.append(name.text)
    locations.append(location.text)
    prices.append(price.text)
    dates_posted.append(date_posted.text)

# %%
df = pd.DataFrame({'Name': names, 'Price':prices,'Location':locations, 'Date':dates_posted, 'Today': datetime.today().
                   strftime('%m/%d/%Y')})

# %%
df
# Out:
#                            Name    Price               Location  \
# 0     2 otaqlı64 m²3/19 mərtəbə   82 000             Əhmədli m.
# 1   2 otaqlı70.2 m²8/14 mərtəbə  119 340           Nərimanov r.
# 2    2 otaqlı63 m²11/16 mərtəbə   80 000             Əhmədli m.
# 3   2 otaqlı80.4 m²9/16 mərtəbə  100 500     7-ci mikrorayon q.
# 4               2 otaqlı74.3 m²  104 777             Yasamal r.
# 5               2 otaqlı73.7 m²  180 638                   Bakı
# 6               2 otaqlı65.2 m²  260 474            Sea Breeze
# 7              2 otaqlı102.5 m²  184 428             Gənclik m.
# 8    2 otaqlı68 m²10/14 mərtəbə  113 500        Həzi Aslanov m.
# 9     2 otaqlı91 m²4/18 mərtəbə  191 000              Nizami m.
# 10     2 otaqlı58 m²1/7 mərtəbə   25 000              Hövsan q.
# 11   2 otaqlı44 m²17/20 mərtəbə   90 000           20 Yanvar m.
# 12    2 otaqlı48 m²2/18 mərtəbə   76 000     9-cu mikrorayon q.
# 13   2 otaqlı70 m²12/12 mərtəbə  130 000         İnşaatçılar m.
# 14    2 otaqlı70 m²7/17 mərtəbə   99 000             Əhmədli m.
# 15  2 otaqlı118 m²11/17 mərtəbə  129 900               Xətai r.
# 16   2 otaqlı82 m²16/20 mərtəbə  124 000              Nəsimi r.
# 17    2 otaqlı72 m²7/20 mərtəbə   89 000             Əhmədli m.
# 18   2 otaqlı93 m²20/20 mərtəbə  145 000         İnşaatçılar m.
# 19   2 otaqlı60 m²14/17 mərtəbə  102 000         Memar Əcəmi m.
# 20     2 otaqlı81 m²3/7 mərtəbə  270 000            Nardaran q.
# 21    2 otaqlı48 m²2/18 mərtəbə   86 000         İnşaatçılar m.
# 22  2 otaqlı100 m²12/17 mərtəbə  169 999  Elmlər Akademiyası m.
# 23   2 otaqlı55 m²14/17 mərtəbə  170 000  Elmlər Akademiyası m.
# 24   2 otaqlı95 m²13/13 mərtəbə  139 000            8 Noyabr m.
# 25   2 otaqlı71 m²16/17 mərtəbə  119 900        Qara Qarayev m.
# 26   2 otaqlı87 m²16/18 mərtəbə  135 000     4-cü mikrorayon q.
# 27   2 otaqlı110 m²8/17 mərtəbə  260 000              Nizami m.
# 28     2 otaqlı82 m²6/6 mərtəbə   62 000             Masazır q.
# 29    2 otaqlı90 m²5/14 mərtəbə  185 000   Nəriman Nərimanov m.
# 30  2 otaqlı100 m²20/27 mərtəbə  180 000             Yasamal q.
# 31   2 otaqlı54 m²13/18 mərtəbə   93 500         İnşaatçılar m.
#
#                    Date       Today
# 0   Bakı, 07 i̇yun 2022  06/14/2022
# 1   Bakı, 04 i̇yun 2022  06/14/2022
# 2     Bakı, dünən 15:48  06/14/2022
# 3     Bakı, dünən 15:16  06/14/2022
# 4     Bakı, 31 may 2022  06/14/2022
# 5   Bakı, 09 i̇yun 2022  06/14/2022
# 6     Bakı, dünən 14:47  06/14/2022
# 7   Bakı, 13 i̇yun 2022  06/14/2022
# 8     Bakı, bugün 01:26  06/14/2022
# 9     Bakı, bugün 00:53  06/14/2022
# 10    Bakı, bugün 00:30  06/14/2022
# 11    Bakı, bugün 00:24  06/14/2022
# 12    Bakı, bugün 00:00  06/14/2022
# 13    Bakı, dünən 23:57  06/14/2022
# 14    Bakı, dünən 23:48  06/14/2022
# 15    Bakı, dünən 23:46  06/14/2022
# 16    Bakı, dünən 23:41  06/14/2022
# 17    Bakı, dünən 23:41  06/14/2022
# 18    Bakı, dünən 23:33  06/14/2022
# 19    Bakı, dünən 23:28  06/14/2022
# 20    Bakı, dünən 23:19  06/14/2022
# 21    Bakı, dünən 23:18  06/14/2022
# 22    Bakı, dünən 22:59  06/14/2022
# 23    Bakı, dünən 22:58  06/14/2022
# 24    Bakı, dünən 22:56  06/14/2022
# 25    Bakı, dünən 22:44  06/14/2022
# 26    Bakı, dünən 22:33  06/14/2022
# 27    Bakı, dünən 22:23  06/14/2022
# 28    Bakı, dünən 22:19  06/14/2022
# 29    Bakı, dünən 22:16  06/14/2022
# 30    Bakı, dünən 22:01  06/14/2022
# 31    Bakı, dünən 21:59  06/14/2022

# %%
df['num_rooms'] = df['Name'].str.split('otaqlı', 1, expand=True)[0]

df['size'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[0]

df['floor'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[1].\
str.split('mərtəbə', 1, expand=True)[0]

# %%
df_1 = df[['num_rooms', 'size', 'floor', 'Price', 'Location', 'Date', 'Today']]

# %%
df_1
# Out:
#    num_rooms    size   floor    Price               Location  \
# 0         2      64    3/19    82 000             Əhmədli m.
# 1         2    70.2    8/14   119 340           Nərimanov r.
# 2         2      63   11/16    80 000             Əhmədli m.
# 3         2    80.4    9/16   100 500     7-ci mikrorayon q.
# 4         2    74.3           104 777             Yasamal r.
# 5         2    73.7           180 638                   Bakı
# 6         2    65.2           260 474            Sea Breeze
# 7         2   102.5           184 428             Gənclik m.
# 8         2      68   10/14   113 500        Həzi Aslanov m.
# 9         2      91    4/18   191 000              Nizami m.
# 10        2      58     1/7    25 000              Hövsan q.
# 11        2      44   17/20    90 000           20 Yanvar m.
# 12        2      48    2/18    76 000     9-cu mikrorayon q.
# 13        2      70   12/12   130 000         İnşaatçılar m.
# 14        2      70    7/17    99 000             Əhmədli m.
# 15        2     118   11/17   129 900               Xətai r.
# 16        2      82   16/20   124 000              Nəsimi r.
# 17        2      72    7/20    89 000             Əhmədli m.
# 18        2      93   20/20   145 000         İnşaatçılar m.
# 19        2      60   14/17   102 000         Memar Əcəmi m.
# 20        2      81     3/7   270 000            Nardaran q.
# 21        2      48    2/18    86 000         İnşaatçılar m.
# 22        2     100   12/17   169 999  Elmlər Akademiyası m.
# 23        2      55   14/17   170 000  Elmlər Akademiyası m.
# 24        2      95   13/13   139 000            8 Noyabr m.
# 25        2      71   16/17   119 900        Qara Qarayev m.
# 26        2      87   16/18   135 000     4-cü mikrorayon q.
# 27        2     110    8/17   260 000              Nizami m.
# 28        2      82     6/6    62 000             Masazır q.
# 29        2      90    5/14   185 000   Nəriman Nərimanov m.
# 30        2     100   20/27   180 000             Yasamal q.
# 31        2      54   13/18    93 500         İnşaatçılar m.
#
#                    Date       Today
# 0   Bakı, 07 i̇yun 2022  06/14/2022
# 1   Bakı, 04 i̇yun 2022  06/14/2022
# 2     Bakı, dünən 15:48  06/14/2022
# 3     Bakı, dünən 15:16  06/14/2022
# 4     Bakı, 31 may 2022  06/14/2022
# 5   Bakı, 09 i̇yun 2022  06/14/2022
# 6     Bakı, dünən 14:47  06/14/2022
# 7   Bakı, 13 i̇yun 2022  06/14/2022
# 8     Bakı, bugün 01:26  06/14/2022
# 9     Bakı, bugün 00:53  06/14/2022
# 10    Bakı, bugün 00:30  06/14/2022
# 11    Bakı, bugün 00:24  06/14/2022
# 12    Bakı, bugün 00:00  06/14/2022
# 13    Bakı, dünən 23:57  06/14/2022
# 14    Bakı, dünən 23:48  06/14/2022
# 15    Bakı, dünən 23:46  06/14/2022
# 16    Bakı, dünən 23:41  06/14/2022
# 17    Bakı, dünən 23:41  06/14/2022
# 18    Bakı, dünən 23:33  06/14/2022
# 19    Bakı, dünən 23:28  06/14/2022
# 20    Bakı, dünən 23:19  06/14/2022
# 21    Bakı, dünən 23:18  06/14/2022
# 22    Bakı, dünən 22:59  06/14/2022
# 23    Bakı, dünən 22:58  06/14/2022
# 24    Bakı, dünən 22:56  06/14/2022
# 25    Bakı, dünən 22:44  06/14/2022
# 26    Bakı, dünən 22:33  06/14/2022
# 27    Bakı, dünən 22:23  06/14/2022
# 28    Bakı, dünən 22:19  06/14/2022
# 29    Bakı, dünən 22:16  06/14/2022
# 30    Bakı, dünən 22:01  06/14/2022
# 31    Bakı, dünən 21:59  06/14/2022

# %% [markdown]
# # for multipe pages

# %%
pip install lxml
pip install html5lib
import lxml
# Out:
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# Collecting lxml
#   Using cached lxml-4.9.0.tar.gz (3.4 MB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: lxml
#   Building wheel for lxml (setup.py) ... done
#   Created wheel for lxml: filename=lxml-4.9.0-cp36-cp36m-macosx_10_6_intel.whl size=3035456 sha256=e1265edf436e59df79104bb8ff4999b6f3780e928aaa8ac31ea3ad6688afbf74
#   Stored in directory: /Users/faridmammadaliyev/Library/Caches/pip/wheels/fe/c7/c1/7bd21552d62c16fe43842f719bd114ebe81f88ee818256519a
# Successfully built lxml
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# Installing collected packages: lxml
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# Successfully installed lxml-4.9.0
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## write a loop for multiple pages

# %%
page = 1
prices=[] #List to store name of the product
locations=[] #List to store price of the product
names=[] #List to store rating of the product
dates_posted=[] 

while page != 2000:
    
    url = f"https://bina.az/baki/alqi-satqi/menziller?page={page}"
    page_main = requests.get(url)
    soup = BeautifulSoup(page_main.content, "html.parser")

    results = soup.find(id="js-items-search")
    job_elements = results.find_all("div", class_="card_params")

    for job_element in job_elements:
        
        name = job_element.find("ul", class_="name")
        location = job_element.find(class_="location")
        price = job_element.find("span", class_="price-val")
        date_posted = job_element.find(class_="city_when")
    
        names.append(name.text)
        locations.append(location.text)
        prices.append(price.text)
        dates_posted.append(date_posted.text)
    
    page = page + 1

# %%
df = pd.DataFrame({'Name': names, 'Price':prices,'Location':locations, 'Date':dates_posted, 'Today': datetime.today().
                   strftime('%m/%d/%Y')})

# %%
df
# Out:
#                                 Name    Price               Location  \
# 0        2 otaqlı108 m²16/19 mərtəbə  138 000               Xətai r.
# 1          3 otaqlı103 m²5/9 mərtəbə  143 156         İnşaatçılar m.
# 2           2 otaqlı48 m²3/5 mərtəbə  110 000              Səbail r.
# 3      3 otaqlı108.1 m²12/13 mərtəbə  153 500           20 Yanvar m.
# 4                   4 otaqlı167.6 m²  251 400              28 May m.
# ...                              ...      ...                    ...
# 37595     2 otaqlı90 m²19/21 mərtəbə  110 000        Yeni Yasamal q.
# 37596     3 otaqlı163 m²9/17 mərtəbə  309 000  Elmlər Akademiyası m.
# 37597    2 otaqlı110 m²11/17 mərtəbə  180 000              Nəsimi r.
# 37598       4 otaqlı90 m²8/9 mərtəbə  168 000   Azadlıq Prospekti m.
# 37599    4 otaqlı185 m²10/16 mərtəbə  635 000   Şah İsmayıl Xətai m.
#
#                       Date       Today
# 0      Bakı, 03 i̇yun 2022  06/15/2022
# 1      Bakı, 12 i̇yun 2022  06/15/2022
# 2      Bakı, 13 i̇yun 2022  06/15/2022
# 3      Bakı, 12 i̇yun 2022  06/15/2022
# 4      Bakı, 10 i̇yun 2022  06/15/2022
# ...                    ...         ...
# 37595    Bakı, 18 may 2022  06/15/2022
# 37596    Bakı, 16 may 2022  06/15/2022
# 37597    Bakı, 12 may 2022  06/15/2022
# 37598  Bakı, 03 i̇yun 2022  06/15/2022
# 37599    Bakı, 10 may 2022  06/15/2022
#
# [37600 rows x 5 columns]

# %%
df['num_rooms'] = df['Name'].str.split('otaqlı', 1, expand=True)[0]

df['size'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[0]

df['floor'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[1].\
str.split('mərtəbə', 1, expand=True)[0]

# %%
df_1 = df[['num_rooms', 'size', 'floor', 'Price', 'Location', 'Date', 'Today']]

# %%
df_1
# Out:
#       num_rooms    size   floor    Price               Location  \
# 0            2     108   16/19   138 000               Xətai r.
# 1            3     103     5/9   143 156         İnşaatçılar m.
# 2            2      48     3/5   110 000              Səbail r.
# 3            3   108.1   12/13   153 500           20 Yanvar m.
# 4            4   167.6           251 400              28 May m.
# ...         ...     ...     ...      ...                    ...
# 37595        2      90   19/21   110 000        Yeni Yasamal q.
# 37596        3     163    9/17   309 000  Elmlər Akademiyası m.
# 37597        2     110   11/17   180 000              Nəsimi r.
# 37598        4      90     8/9   168 000   Azadlıq Prospekti m.
# 37599        4     185   10/16   635 000   Şah İsmayıl Xətai m.
#
#                       Date       Today
# 0      Bakı, 03 i̇yun 2022  06/15/2022
# 1      Bakı, 12 i̇yun 2022  06/15/2022
# 2      Bakı, 13 i̇yun 2022  06/15/2022
# 3      Bakı, 12 i̇yun 2022  06/15/2022
# 4      Bakı, 10 i̇yun 2022  06/15/2022
# ...                    ...         ...
# 37595    Bakı, 18 may 2022  06/15/2022
# 37596    Bakı, 16 may 2022  06/15/2022
# 37597    Bakı, 12 may 2022  06/15/2022
# 37598  Bakı, 03 i̇yun 2022  06/15/2022
# 37599    Bakı, 10 may 2022  06/15/2022
#
# [37600 rows x 7 columns]

# %%
df.to_csv('houses_baku.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('houses_baku.csv')

# %%
df['num_rooms'] = df['Name'].str.split('otaqlı', 1, expand=True)[0]

df['size'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[0]

df['floor'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[1].\
str.split('mərtəbə', 1, expand=True)[0]

# %%
df_1 = df[['num_rooms', 'size', 'floor', 'Price', 'Location', 'Date', 'Today']]

# %%
df_1
# Out:
#       num_rooms    size   floor    Price               Location  \
# 0            2     108   16/19   138 000               Xətai r.
# 1            3     103     5/9   143 156         İnşaatçılar m.
# 2            2      48     3/5   110 000              Səbail r.
# 3            3   108.1   12/13   153 500           20 Yanvar m.
# 4            4   167.6           251 400              28 May m.
# ...         ...     ...     ...      ...                    ...
# 37595        2      90   19/21   110 000        Yeni Yasamal q.
# 37596        3     163    9/17   309 000  Elmlər Akademiyası m.
# 37597        2     110   11/17   180 000              Nəsimi r.
# 37598        4      90     8/9   168 000   Azadlıq Prospekti m.
# 37599        4     185   10/16   635 000   Şah İsmayıl Xətai m.
#
#                       Date       Today
# 0      Bakı, 03 i̇yun 2022  06/15/2022
# 1      Bakı, 12 i̇yun 2022  06/15/2022
# 2      Bakı, 13 i̇yun 2022  06/15/2022
# 3      Bakı, 12 i̇yun 2022  06/15/2022
# 4      Bakı, 10 i̇yun 2022  06/15/2022
# ...                    ...         ...
# 37595    Bakı, 18 may 2022  06/15/2022
# 37596    Bakı, 16 may 2022  06/15/2022
# 37597    Bakı, 12 may 2022  06/15/2022
# 37598  Bakı, 03 i̇yun 2022  06/15/2022
# 37599    Bakı, 10 may 2022  06/15/2022
#
# [37600 rows x 7 columns]

# %%
df_1.to_csv('houses_baku_parsered.csv', index=False, encoding='utf-8')

# %%
import pandas as pd

df_1 = pd.read_csv('houses_baku_parsered.csv')

# %%
df_1
# Out:
#        num_rooms   size   floor    Price               Location  \
# 0              2  108.0  16/19   138 000               Xətai r.
# 1              3  103.0    5/9   143 156         İnşaatçılar m.
# 2              2   48.0    3/5   110 000              Səbail r.
# 3              3  108.1  12/13   153 500           20 Yanvar m.
# 4              4  167.6     NaN  251 400              28 May m.
# ...          ...    ...     ...      ...                    ...
# 37595          2   90.0  19/21   110 000        Yeni Yasamal q.
# 37596          3  163.0   9/17   309 000  Elmlər Akademiyası m.
# 37597          2  110.0  11/17   180 000              Nəsimi r.
# 37598          4   90.0    8/9   168 000   Azadlıq Prospekti m.
# 37599          4  185.0  10/16   635 000   Şah İsmayıl Xətai m.
#
#                       Date       Today
# 0      Bakı, 03 i̇yun 2022  06/15/2022
# 1      Bakı, 12 i̇yun 2022  06/15/2022
# 2      Bakı, 13 i̇yun 2022  06/15/2022
# 3      Bakı, 12 i̇yun 2022  06/15/2022
# 4      Bakı, 10 i̇yun 2022  06/15/2022
# ...                    ...         ...
# 37595    Bakı, 18 may 2022  06/15/2022
# 37596    Bakı, 16 may 2022  06/15/2022
# 37597    Bakı, 12 may 2022  06/15/2022
# 37598  Bakı, 03 i̇yun 2022  06/15/2022
# 37599    Bakı, 10 may 2022  06/15/2022
#
# [37600 rows x 7 columns]

# %%
df_1['Price'] = df_1['Price'].str.replace(' ', '').astype(int)

# %%
df_1.dtypes
# Out:
# num_rooms      int64
# size         float64
# floor         object
# Price          int64
# Location      object
# Date          object
# Today         object
# dtype: object

# %%
df_1.describe()
# Out:
#           num_rooms           size         Price
# count  37600.000000   37600.000000  3.760000e+04
# mean       2.785691     114.175072  2.019396e+05
# std        1.051850     852.950803  1.887489e+05
# min        1.000000       3.000000  1.500000e+03
# 25%        2.000000      69.000000  1.100000e+05
# 50%        3.000000      97.000000  1.550000e+05
# 75%        3.000000     135.000000  2.399990e+05
# max       20.000000  165000.000000  5.000000e+06

# %%
# if you are using pandas and would like to suppress scientific notation for all floats, is to adjust the pandas options.




pd.options.display.float_format = '{:.2f}'.format

# %%
df_1.describe()
# Out:
#        num_rooms      size      Price
# count   37600.00  37600.00   37600.00
# mean        2.79    114.18  201939.58
# std         1.05    852.95  188748.93
# min         1.00      3.00    1500.00
# 25%         2.00     69.00  110000.00
# 50%         3.00     97.00  155000.00
# 75%         3.00    135.00  239999.00
# max        20.00 165000.00 5000000.00

# %%
df_1['floor_current'] = df_1['floor'].str.split('/', 1, expand=True)[0]

# %%
df_1['floor_max'] = df_1['floor'].str.split('/', 1, expand=True)[1]

# %%
df_1['floor_current'] = df_1['floor_current'][pd.notnull(df_1['floor_current'])].astype('int')

# %%
df_1['floor_max'] = df_1['floor_max'][pd.notnull(df_1['floor_max'])].astype('int')

# %%
df_1.dtypes
# Out:
# num_rooms          int64
# size             float64
# floor             object
# Price              int64
# Location          object
# Date              object
# Today             object
# floor_current    float64
# floor_max        float64
# dtype: object

# %%
df_1['floor_ratio'] = df_1['floor_current']/df_1['floor_max']

# %%
df_1.columns
# Out:
# Index(['num_rooms', 'size', 'floor', 'Price', 'Location', 'Date', 'Today',
#        'floor_current', 'floor_max', 'floor_ratio'],
#       dtype='object')

# %%
df_1[['num_rooms', 'size', 'floor_ratio',  'Location', 'Date', 'Today', 'floor', 'floor_current', 'floor_max'
     , 'Price']]
# Out:
#        num_rooms   size  floor_ratio               Location  \
# 0              2 108.00         0.84               Xətai r.
# 1              3 103.00         0.56         İnşaatçılar m.
# 2              2  48.00         0.60              Səbail r.
# 3              3 108.10         0.92           20 Yanvar m.
# 4              4 167.60          nan              28 May m.
# ...          ...    ...          ...                    ...
# 37595          2  90.00         0.90        Yeni Yasamal q.
# 37596          3 163.00         0.53  Elmlər Akademiyası m.
# 37597          2 110.00         0.65              Nəsimi r.
# 37598          4  90.00         0.89   Azadlıq Prospekti m.
# 37599          4 185.00         0.62   Şah İsmayıl Xətai m.
#
#                       Date       Today   floor  floor_current  floor_max  \
# 0      Bakı, 03 i̇yun 2022  06/15/2022  16/19           16.00      19.00
# 1      Bakı, 12 i̇yun 2022  06/15/2022    5/9            5.00       9.00
# 2      Bakı, 13 i̇yun 2022  06/15/2022    3/5            3.00       5.00
# 3      Bakı, 12 i̇yun 2022  06/15/2022  12/13           12.00      13.00
# 4      Bakı, 10 i̇yun 2022  06/15/2022     NaN            nan        nan
# ...                    ...         ...     ...            ...        ...
# 37595    Bakı, 18 may 2022  06/15/2022  19/21           19.00      21.00
# 37596    Bakı, 16 may 2022  06/15/2022   9/17            9.00      17.00
# 37597    Bakı, 12 may 2022  06/15/2022  11/17           11.00      17.00
# 37598  Bakı, 03 i̇yun 2022  06/15/2022    8/9            8.00       9.00
# 37599    Bakı, 10 may 2022  06/15/2022  10/16           10.00      16.00
#
#         Price
# 0      138000
# 1      143156
# 2      110000
# 3      153500
# 4      251400
# ...       ...
# 37595  110000
# 37596  309000
# 37597  180000
# 37598  168000
# 37599  635000
#
# [37600 rows x 10 columns]

# %% [markdown]
# # Start the analysis

# %%
df_1.describe([.01,.1,.2,.3,.4,.5,.6,.7,.8,.9,.99])
# Out:
#        num_rooms      size      Price  floor_current  floor_max  floor_ratio
# count   37600.00  37600.00   37600.00       32717.00   32717.00     32717.00
# mean        2.79    114.18  201939.58           8.09      13.92         0.59
# std         1.05    852.95  188748.93           4.96       5.37         0.27
# min         1.00      3.00    1500.00           1.00       1.00         0.05
# 1%          1.00     35.00   52000.00           1.00       3.00         0.11
# 10%         2.00     53.00   80000.00           2.00       5.00         0.21
# 20%         2.00     65.00   99500.00           3.00       9.00         0.31
# 30%         2.00     72.10  119000.00           5.00      10.00         0.41
# 40%         3.00     84.00  135000.00           6.00      15.00         0.50
# 50%         3.00     97.00  155000.00           7.00      16.00         0.60
# 60%         3.00    110.00  179000.00           9.00      17.00         0.69
# 70%         3.00    126.00  215000.00          11.00      17.00         0.79
# 80%         3.00    145.00  265000.00          13.00      18.00         0.88
# 90%         4.00    178.00  359000.00          16.00      19.00         0.95
# 99%         5.00    308.00  830100.00          19.84      27.00         1.00
# max        20.00 165000.00 5000000.00          27.00      33.00         1.00

# %%
# correlation


df_1[['num_rooms', 'size', 'floor_current', 'floor_max', 'floor_ratio', 'Price' ]].corr()
# Out:
#                num_rooms  size  floor_current  floor_max  floor_ratio  Price
# num_rooms           1.00  0.06           0.08       0.07         0.05   0.58
# size                0.06  1.00           0.01       0.03        -0.00   0.06
# floor_current       0.08  0.01           1.00       0.61         0.68   0.14
# floor_max           0.07  0.03           0.61       1.00        -0.09   0.24
# floor_ratio         0.05 -0.00           0.68      -0.09         1.00  -0.02
# Price               0.58  0.06           0.14       0.24        -0.02   1.00

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37600 entries, 0 to 37599
# Data columns (total 10 columns):
# num_rooms        37600 non-null int64
# size             37600 non-null float64
# floor            32717 non-null object
# Price            37600 non-null int64
# Location         37600 non-null object
# Date             37600 non-null object
# Today            37600 non-null object
# floor_current    32717 non-null float64
# floor_max        32717 non-null float64
# floor_ratio      32717 non-null float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 2.9+ MB

# %%
import matplotlib.pyplot as plt

fig_ = df_1.hist(figsize=(15, 10), bins=50, color="darkcyan", edgecolor="black", xlabelsize=8, ylabelsize=8)

plt.show()

# %%
import seaborn as sns

fig = plt.figure(figsize=(30,50))
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=1.9,
                    wspace=0.3,
                    hspace=0.5)
for i, col in enumerate(df_1[['num_rooms', 'size', 'floor_current', 'floor_max', 'floor_ratio', 'Price' ]].columns):
        plt.subplot(15,3,i+1)
        sns.regplot(x=col, y= "Price", data=df_1[['num_rooms', 'size', 'floor_current', 'floor_max', 'floor_ratio', 'Price' ]], scatter_kws={"color": "darkslateblue"}, line_kws={"color": "red"})

# %%
df_1['Price'].quantile(.99)
# Out:
# 830100.0000000204

# %%
df_1[df_1['Price'] <= df_1['Price'].quantile(.99)]
# Out:
#        num_rooms   size   floor   Price               Location  \
# 0              2 108.00  16/19   138000               Xətai r.
# 1              3 103.00    5/9   143156         İnşaatçılar m.
# 2              2  48.00    3/5   110000              Səbail r.
# 3              3 108.10  12/13   153500           20 Yanvar m.
# 4              4 167.60     NaN  251400              28 May m.
# ...          ...    ...     ...     ...                    ...
# 37595          2  90.00  19/21   110000        Yeni Yasamal q.
# 37596          3 163.00   9/17   309000  Elmlər Akademiyası m.
# 37597          2 110.00  11/17   180000              Nəsimi r.
# 37598          4  90.00    8/9   168000   Azadlıq Prospekti m.
# 37599          4 185.00  10/16   635000   Şah İsmayıl Xətai m.
#
#                       Date       Today  floor_current  floor_max  floor_ratio
# 0      Bakı, 03 i̇yun 2022  06/15/2022          16.00      19.00         0.84
# 1      Bakı, 12 i̇yun 2022  06/15/2022           5.00       9.00         0.56
# 2      Bakı, 13 i̇yun 2022  06/15/2022           3.00       5.00         0.60
# 3      Bakı, 12 i̇yun 2022  06/15/2022          12.00      13.00         0.92
# 4      Bakı, 10 i̇yun 2022  06/15/2022            nan        nan          nan
# ...                    ...         ...            ...        ...          ...
# 37595    Bakı, 18 may 2022  06/15/2022          19.00      21.00         0.90
# 37596    Bakı, 16 may 2022  06/15/2022           9.00      17.00         0.53
# 37597    Bakı, 12 may 2022  06/15/2022          11.00      17.00         0.65
# 37598  Bakı, 03 i̇yun 2022  06/15/2022           8.00       9.00         0.89
# 37599    Bakı, 10 may 2022  06/15/2022          10.00      16.00         0.62
#
# [37224 rows x 10 columns]

# %%
df_99 = df_1[(df_1['Price'] <= df_1['Price'].quantile(.99))
    & (df_1['size'] <= df_1['size'].quantile(.99))
    & (df_1['num_rooms'] <= df_1['num_rooms'].quantile(.99))
    & (df_1['floor_current'] <= df_1['floor_current'].quantile(.99))
    & (df_1['floor_max'] <= df_1['floor_max'].quantile(.99))
    & (df_1['floor_ratio'] <= df_1['floor_ratio'].quantile(.99))]

# %%
df_99.describe([.01,.1,.2,.3,.4,.5,.6,.7,.8,.9,.99])
# Out:
#        num_rooms     size     Price  floor_current  floor_max  floor_ratio
# count   31789.00 31789.00  31789.00       31789.00   31789.00     31789.00
# mean        2.77   104.04 182969.34           7.92      13.78         0.59
# std         0.85    45.87 109378.48           4.75       5.23         0.27
# min         1.00     3.00   1500.00           1.00       1.00         0.05
# 1%          1.00    35.00  50000.00           1.00       3.00         0.11
# 10%         2.00    54.00  81000.00           2.00       5.00         0.21
# 20%         2.00    64.00  99900.00           3.00       9.00         0.31
# 30%         2.00    73.00 118000.00           5.00      10.00         0.41
# 40%         3.00    85.00 135000.00           6.00      15.00         0.50
# 50%         3.00    96.00 153000.00           7.00      16.00         0.59
# 60%         3.00   108.20 175000.00           9.00      17.00         0.67
# 70%         3.00   122.00 206000.00          10.00      17.00         0.78
# 80%         3.00   140.00 250000.00          12.00      18.00         0.86
# 90%         4.00   167.00 320000.00          15.00      19.00         0.94
# 99%         5.00   242.00 585360.00          18.00      23.00         1.00
# max         5.00   305.00 830000.00          19.00      27.00         1.00

# %%
import matplotlib.pyplot as plt

fig_ = df_99.hist(figsize=(15, 10), bins=50, color="darkcyan", edgecolor="black", xlabelsize=8, ylabelsize=8)

plt.show()

# %%
import seaborn as sns

fig = plt.figure(figsize=(30,50))
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=1.9,
                    wspace=0.3,
                    hspace=0.5)
for i, col in enumerate(df_99[['num_rooms', 'size', 'floor_current', 'floor_max', 'floor_ratio', 'Price' ]].columns):
        plt.subplot(15,3,i+1)
        sns.regplot(x=col, y= "Price", data=df_99[['num_rooms', 'size', 'floor_current', 'floor_max', 'floor_ratio', 'Price' ]], scatter_kws={"color": "darkslateblue"}, line_kws={"color": "red"})

# %%
df_99.columns
# Out:
# Index(['num_rooms', 'size', 'floor', 'Price', 'Location', 'Date', 'Today',
#        'floor_current', 'floor_max', 'floor_ratio'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(20, 10))
sns.set_style("whitegrid")




df_99['Location'].value_counts().head(30).plot.bar(rot=0, subplots=True)

plt.xticks(rotation=90, fontsize = 12)

plt.title('Number of houses per location\n', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Number of houses per location\n')

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig = plt.figure(figsize=(20, 10))
sns.set_style("whitegrid")


df_99.groupby('Location')['Price'].mean().sort_values(ascending = False).head(40).plot.bar(rot=0, subplots=True)

plt.xticks(rotation=90, fontsize = 14)

plt.yticks(fontsize = 14)


plt.title('Mean price per location\n', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Mean price per location\n')

# %% [markdown]
# ## mean price for number of rooms

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig = plt.figure(figsize=(20, 10))
sns.set_style("whitegrid")


df_99.groupby('num_rooms')['Price'].mean().sort_values(ascending = False).head(40).plot.bar(rot=0, subplots=True)

plt.xticks(fontsize = 14)

plt.yticks(fontsize = 14)


plt.title('Mean price per number of rooms\n', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Mean price per number of rooms\n')

# %%
df_99[['num_rooms', 'size', 'floor_ratio', 'Price' ]].corr()
# Out:
#              num_rooms  size  floor_ratio  Price
# num_rooms         1.00  0.75         0.02   0.59
# size              0.75  1.00        -0.04   0.82
# floor_ratio       0.02 -0.04         1.00  -0.06
# Price             0.59  0.82        -0.06   1.00

# %%
df_99
# Out:
#        num_rooms   size   floor   Price               Location  \
# 0              2 108.00  16/19   138000               Xətai r.
# 1              3 103.00    5/9   143156         İnşaatçılar m.
# 2              2  48.00    3/5   110000              Səbail r.
# 3              3 108.10  12/13   153500           20 Yanvar m.
# 8              1  67.00  17/18    82500            Badamdar q.
# ...          ...    ...     ...     ...                    ...
# 37595          2  90.00  19/21   110000        Yeni Yasamal q.
# 37596          3 163.00   9/17   309000  Elmlər Akademiyası m.
# 37597          2 110.00  11/17   180000              Nəsimi r.
# 37598          4  90.00    8/9   168000   Azadlıq Prospekti m.
# 37599          4 185.00  10/16   635000   Şah İsmayıl Xətai m.
#
#                       Date       Today  floor_current  floor_max  floor_ratio
# 0      Bakı, 03 i̇yun 2022  06/15/2022          16.00      19.00         0.84
# 1      Bakı, 12 i̇yun 2022  06/15/2022           5.00       9.00         0.56
# 2      Bakı, 13 i̇yun 2022  06/15/2022           3.00       5.00         0.60
# 3      Bakı, 12 i̇yun 2022  06/15/2022          12.00      13.00         0.92
# 8        Bakı, bugün 15:13  06/15/2022          17.00      18.00         0.94
# ...                    ...         ...            ...        ...          ...
# 37595    Bakı, 18 may 2022  06/15/2022          19.00      21.00         0.90
# 37596    Bakı, 16 may 2022  06/15/2022           9.00      17.00         0.53
# 37597    Bakı, 12 may 2022  06/15/2022          11.00      17.00         0.65
# 37598  Bakı, 03 i̇yun 2022  06/15/2022           8.00       9.00         0.89
# 37599    Bakı, 10 may 2022  06/15/2022          10.00      16.00         0.62
#
# [31789 rows x 10 columns]

# %% [markdown]
# # I do the scrapping again to collect extra data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

page = 1

data=[] #List to store price of the product

while page != 2:
    print(f'Scraping page {page}')
    
    url = f"https://bina.az/baki/alqi-satqi/menziller?page={page}"
    page_main = requests.get(url)
    soup = BeautifulSoup(page_main.content, "html.parser")

    for results in soup.find_all('div',class_='items_list'):        #there are multiple listing containers
        for item in results.find_all('div',class_='items-i'):

            location = item.find(class_="location").text.strip()
            
            try:
                bill = item.find('div',class_='bill_of_sale').find('span').text.strip()
            except AttributeError:
                bill = ''

            try:
                mort = item.find('div',class_='mortgage').find('span').text.strip()
            except AttributeError:
                mort = ''

            price = item.find('div',class_='price').text.strip()
                    
            rooms,size,floor = ('','','')
            for detail in item.find('ul',class_='name').find_all('li'):
                if 'otaqlı' in detail.text:
                    rooms = detail.text.strip()
                elif 'm²' in detail.text:
                    size = detail.text.strip()
                elif 'mərtəbə' in detail.text:
                    floor = detail.text.strip()
                
    
            item = {
                'location':location,
                'bill':bill,
                'mortage':mort,
                'price': price,
                'rooms':rooms,
                'size':size,
                'floor':floor
                }

            data.append(item)

    page += 1
    
df = pd.DataFrame(data)
#df.to_csv('locations.csv',index=False)
# Out:
# Scraping page 1

# %%
df.head(10)
# Out:
#                location       bill      mortage       price     rooms  \
# 0              Sahil m.  Kupça var               279 000AZN  4 otaqlı
# 1             Nəsimi r.  Kupça var               270 000AZN  3 otaqlı
# 2              Xətai r.                          129 000AZN  3 otaqlı
# 3  Nəriman Nərimanov m.                          161 000AZN  2 otaqlı
# 4            Sea Breeze                          173 731AZN  2 otaqlı
# 5                  Bakı                          180 638AZN  2 otaqlı
# 6                  Bakı                          124 337AZN  3 otaqlı
# 7                  Bakı                          323 000AZN  3 otaqlı
# 8  Şah İsmayıl Xətai m.  Kupça var  İpoteka var  250 000AZN  3 otaqlı
# 9            Yasamal r.                          208 000AZN  3 otaqlı
#
#       size          floor
# 0   110 m²    3/4 mərtəbə
# 1   116 m²   4/17 mərtəbə
# 2   147 m²   8/13 mərtəbə
# 3    61 m²   6/11 mərtəbə
# 4  75.7 m²
# 5  73.7 m²
# 6  99.5 m²
# 7   170 m²
# 8   117 m²  11/16 mərtəbə
# 9   148 m²  11/27 mərtəbə

# %%
df['currency'] = df['price'].str[-3:]

# %%
df['price_cleaned'] = df['price'].map(lambda x: str(x)[:-3]).str.replace(' ', '').astype(int)

# %%
df['rooms_cleaned'] = df['rooms'].str.split('otaqlı', 1, expand=True)[0]

# %%
df['size_cleaned'] = df['size'].str.split('m²', 1, expand=True)[0]

# %%
df['floor_cleaned'] = df['floor'].str.split('mərtəbə', 1, expand=True)[0]

# %%
df
# Out:
#                  location       bill      mortage       price     rooms  \
# 0    Nəriman Nərimanov m.             İpoteka var  118 450AZN  1 otaqlı
# 1            Nərimanov r.  Kupça var  İpoteka var   86 640AZN  1 otaqlı
# 2               28 May m.                          113 000AZN  2 otaqlı
# 3            Nərimanov r.  Kupça var               319 000AZN  3 otaqlı
# 4                    Bakı                          279 335AZN  3 otaqlı
# 5                    Bakı                          116 110AZN  1 otaqlı
# 6                    Bakı                          316 756AZN  3 otaqlı
# 7              Sea Breeze                          263 814AZN  2 otaqlı
# 8            Neftçilər m.                          162 000AZN  3 otaqlı
# 9             Nardaran q.  Kupça var  İpoteka var  291 465AZN  3 otaqlı
# 10            Nardaran q.  Kupça var  İpoteka var  213 435AZN  3 otaqlı
# 11         İnşaatçılar m.  Kupça var  İpoteka var  169 000AZN  3 otaqlı
# 12            Nardaran q.  Kupça var  İpoteka var  174 420AZN  2 otaqlı
# 13             Gənclik m.  Kupça var                85 000AZN  2 otaqlı
# 14         İnşaatçılar m.  Kupça var  İpoteka var  169 000AZN  3 otaqlı
# 15            Nardaran q.  Kupça var  İpoteka var  165 240AZN  2 otaqlı
# 16           20 Yanvar m.  Kupça var               179 500AZN  3 otaqlı
# 17   Nəriman Nərimanov m.  Kupça var               205 000AZN  3 otaqlı
# 18             Sea Breeze                          160 658AZN  1 otaqlı
# 19             Əhmədli q.  Kupça var                85 000AZN  3 otaqlı
# 20             Sea Breeze                          260 474AZN  2 otaqlı
# 21             Sea Breeze                          263 814AZN  2 otaqlı
# 22         İnşaatçılar m.  Kupça var  İpoteka var  150 000AZN  3 otaqlı
# 23              Nizami m.  Kupça var                62 000AZN  2 otaqlı
# 24              Nizami m.  Kupça var               102 000AZN  2 otaqlı
# 25        Qara Qarayev m.  Kupça var                66 000AZN  1 otaqlı
# 26        Həzi Aslanov m.  Kupça var               120 000AZN  3 otaqlı
# 27             Sea Breeze                          122 553AZN  1 otaqlı
# 28             Sea Breeze                          147 109AZN  1 otaqlı
# 29  Elmlər Akademiyası m.  Kupça var               600 000AZN  3 otaqlı
# 30           Nərimanov r.  Kupça var  İpoteka var  207 000AZN  3 otaqlı
# 31         Memar Əcəmi m.  Kupça var                70 000AZN  2 otaqlı
#
#         size          floor currency  price_cleaned rooms_cleaned  \
# 0    51.5 m²   7/15 mərtəbə      AZN         118450            1
# 1    45.6 m²  14/16 mərtəbə      AZN          86640            1
# 2      67 m²  12/16 mərtəbə      AZN         113000            2
# 3     149 m²  11/18 mərtəbə      AZN         319000            3
# 4   121.5 m²                     AZN         279335            3
# 5    68.3 m²                     AZN         116110            1
# 6   137.7 m²                     AZN         316756            3
# 7    75.7 m²                     AZN         263814            2
# 8      90 m²  13/17 mərtəbə      AZN         162000            3
# 9     127 m²    2/7 mərtəbə      AZN         291465            3
# 10     93 m²    2/7 mərtəbə      AZN         213435            3
# 11    110 m²   3/18 mərtəbə      AZN         169000            3
# 12     76 m²    2/7 mərtəbə      AZN         174420            2
# 13     50 m²    4/4 mərtəbə      AZN          85000            2
# 14    112 m²  15/18 mərtəbə      AZN         169000            3
# 15     72 m²    2/7 mərtəbə      AZN         165240            2
# 16    130 m²   6/20 mərtəbə      AZN         179500            3
# 17    116 m²  15/19 mərtəbə      AZN         205000            3
# 18   46.1 m²                     AZN         160658            1
# 19     80 m²    9/9 mərtəbə      AZN          85000            3
# 20   65.2 m²                     AZN         260474            2
# 21   75.7 m²                     AZN         263814            2
# 22     90 m²    8/9 mərtəbə      AZN         150000            3
# 23     28 m²    2/4 mərtəbə      AZN          62000            2
# 24     45 m²    2/6 mərtəbə      AZN         102000            2
# 25     35 m²    3/5 mərtəbə      AZN          66000            1
# 26     90 m²  15/17 mərtəbə      AZN         120000            3
# 27   53.4 m²                     AZN         122553            1
# 28   64.1 m²                     AZN         147109            1
# 29    162 m²   4/17 mərtəbə      AZN         600000            3
# 30    102 m²  14/15 mərtəbə      AZN         207000            3
# 31     50 m²    2/5 mərtəbə      AZN          70000            2
#
#    size_cleaned floor_cleaned
# 0         51.5          7/15
# 1         45.6         14/16
# 2           67         12/16
# 3          149         11/18
# 4        121.5
# 5         68.3
# 6        137.7
# 7         75.7
# 8           90         13/17
# 9          127           2/7
# 10          93           2/7
# 11         110          3/18
# 12          76           2/7
# 13          50           4/4
# 14         112         15/18
# 15          72           2/7
# 16         130          6/20
# 17         116         15/19
# 18        46.1
# 19          80           9/9
# 20        65.2
# 21        75.7
# 22          90           8/9
# 23          28           2/4
# 24          45           2/6
# 25          35           3/5
# 26          90         15/17
# 27        53.4
# 28        64.1
# 29         162          4/17
# 30         102         14/15
# 31          50           2/5

# %% [markdown]
# # now let's write another loop to extract data for all types of object types

# %%
object_types = ['menziller', 'menziller/yeni-tikili', 'menziller/kohne-tikili', 'evler', 'baglar', 'ofisler',
               'qarajlar', 'torpaq', 'obyektler']

# %%
object_types[0]
# Out:
# 'menziller'

# %%
len(object_types)
# Out:
# 9

# %%
page = 1 


while page != 3:
    
    for i in range(len(object_types)):
        
        url = f"https://bina.az/baki/alqi-satqi/{object_types[i]}?page={page}"
        
        print(f'{url}')
        
    page += 1
# Out:
# https://bina.az/baki/alqi-satqi/menziller?page=1
# https://bina.az/baki/alqi-satqi/menziller/yeni-tikili?page=1
# https://bina.az/baki/alqi-satqi/menziller/kohne-tikili?page=1
# https://bina.az/baki/alqi-satqi/evler?page=1
# https://bina.az/baki/alqi-satqi/baglar?page=1
# https://bina.az/baki/alqi-satqi/ofisler?page=1
# https://bina.az/baki/alqi-satqi/qarajlar?page=1
# https://bina.az/baki/alqi-satqi/torpaq?page=1
# https://bina.az/baki/alqi-satqi/obyektler?page=1
# https://bina.az/baki/alqi-satqi/menziller?page=2
# https://bina.az/baki/alqi-satqi/menziller/yeni-tikili?page=2
# https://bina.az/baki/alqi-satqi/menziller/kohne-tikili?page=2
# https://bina.az/baki/alqi-satqi/evler?page=2
# https://bina.az/baki/alqi-satqi/baglar?page=2
# https://bina.az/baki/alqi-satqi/ofisler?page=2
# https://bina.az/baki/alqi-satqi/qarajlar?page=2
# https://bina.az/baki/alqi-satqi/torpaq?page=2
# https://bina.az/baki/alqi-satqi/obyektler?page=2

# %%
object_types = ['menziller', 'menziller/yeni-tikili', 'menziller/kohne-tikili', 'evler', 'baglar', 'ofisler',
               'qarajlar', 'torpaq', 'obyektler']

data=[] #List to store price of the product

page = 1

while page != 3:

    print(f'Scraping page: {page}')
    
    
    for i in range(len(object_types)):
        
        print(f'Object type: {object_types[i]}')
        
        url = f"https://bina.az/baki/alqi-satqi/{object_types[i]}?page={page}"
       
    
        page_main = requests.get(url)
        soup = BeautifulSoup(page_main.content, "html.parser")
        
        
        
        for results in soup.find_all('div',class_='items_list'):        #there are multiple listing containe
            
            for item in results.find_all('div',class_='items-i'):
                
                location = item.find(class_="location").text.strip()
                
                try:
                    bill = item.find('div',class_='bill_of_sale').find('span').text.strip()
                except AttributeError:
                    bill = ''

                try:
                    mort = item.find('div',class_='mortgage').find('span').text.strip()
                except AttributeError:
                    mort = ''

                price = item.find('div',class_='price').text.strip()
                 
                object_type = object_types[i]
                page_number = page
                
                rooms,size,floor = ('','','')
                
                time_posted = item.find('div',class_='city_when').text.strip()
                
                
                for detail in item.find('ul',class_='name').find_all('li'):
                    
                    if 'otaqlı' in detail.text:
                        rooms = detail.text.strip()
                    elif 'm²' in detail.text:
                        size = detail.text.strip()
                    elif 'mərtəbə' in detail.text:
                        floor = detail.text.strip()
                    
                    
                item = {
                    'location':location,
                    'bill':bill,
                    'mortage':mort,
                    'price': price,
                    'rooms':rooms,
                    'size':size,
                    'floor':floor,
                    'object_type':  object_type,
                    'page_number': page_number,
                    'time_posted': time_posted
                    }

                data.append(item)
                    
                    
    page += 1
    
    
df = pd.DataFrame(data)

df
# Out:
# Scraping page: 1
# Object type: menziller
# Object type: menziller/yeni-tikili
# Object type: menziller/kohne-tikili
# Object type: evler
# Object type: baglar
# Object type: ofisler
# Object type: qarajlar
# Object type: torpaq
# Object type: obyektler
# Scraping page: 2
# Object type: menziller
# Object type: menziller/yeni-tikili
# Object type: menziller/kohne-tikili
# Object type: evler
# Object type: baglar
# Object type: ofisler
# Object type: qarajlar
# Object type: torpaq
# Object type: obyektler
#            location       bill      mortage         price     rooms      size  \
# 0         Nəsimi r.             İpoteka var    133 100AZN  2 otaqlı   60.5 m²
# 1        Kubinka q.  Kupça var                 305 000AZN  3 otaqlı    151 m²
# 2         Nizami m.  Kupça var                 275 000AZN  4 otaqlı    170 m²
# 3        Əhmədli q.  Kupça var                  55 000AZN  3 otaqlı   44.2 m²
# 4              Bakı                            182 837AZN  4 otaqlı  146.3 m²
# ..              ...        ...          ...           ...       ...       ...
# 511    Neftçilər m.                          2 300 000AZN              570 m²
# 512  İnşaatçılar m.  Kupça var               1 100 000AZN              390 m²
# 513       Nəsimi r.  Kupça var                 500 000AZN              200 m²
# 514        Xətai r.  Kupça var                 750 000AZN              280 m²
# 515        Sahil m.  Kupça var  İpoteka var    900 000AZN               90 m²
#
#              floor object_type  page_number          time_posted
# 0     3/16 mərtəbə   menziller            1    Bakı, dünən 11:40
# 1    12/16 mərtəbə   menziller            1    Bakı, 27 may 2022
# 2    18/20 mərtəbə   menziller            1  Bakı, 14 i̇yun 2022
# 3      1/2 mərtəbə   menziller            1  Bakı, 16 i̇yun 2022
# 4                    menziller            1    Bakı, bugün 10:39
# ..             ...         ...          ...                  ...
# 511                  obyektler            2    Bakı, bugün 11:00
# 512                  obyektler            2    Bakı, bugün 10:59
# 513                  obyektler            2    Bakı, bugün 10:48
# 514                  obyektler            2    Bakı, bugün 10:42
# 515                  obyektler            2    Bakı, bugün 10:38
#
# [516 rows x 10 columns]

# %%
df['object_type'].value_counts()
# Out:
# menziller/yeni-tikili     64
# menziller                 64
# baglar                    56
# torpaq                    56
# menziller/kohne-tikili    56
# qarajlar                  56
# evler                     56
# obyektler                 56
# ofisler                   52
# Name: object_type, dtype: int64

# %%
df['bill'].value_counts()
# Out:
# Kupça var    419
#               97
# Name: bill, dtype: int64
