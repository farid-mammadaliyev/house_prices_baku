# %%
from selenium import webdriver
#from BeautifulSoup import BeautifulSoup

from bs4 import BeautifulSoup
import pandas as pd
import requests

import datetime 
from datetime import datetime

# %%
URL = "https://bina.az/baki/alqi-satqi/menziller/yeni-tikili/2-otaqli?items_view=list"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
results = soup.find(id="js-items-search")

# %%
print(results.prettify())
# Out:
# <div class="items" id="js-items-search">
#  <section class="vipped_row thumblist row vipped-pure">
#   <header class="section-header">
#    <div class="thumblist-title">
#     VIP Elanlar
#    </div>
#    <a class="show-all" href="/items/vipped?q%5Bcategory_id%5D=2&amp;q%5Bleased%5D=false" target="_blank">
#     Bütün VIP Elanlar
#    </a>
#   </header>
#   <div class="items_list items">
#    <div class="items-i vipped">
#     <a class="item_link" href="/items/2820516" target="_blank">
#     </a>
#     <div class="bookmarking card_view">
#      <a class="add_bookmark" data-disable="true" data-method="post" data-remote="true" href="/bookmarks?card_view=true&amp;item_id=2820516" rel="nofollow">
#      </a>
#     </div>
#     <div class="preview">
#      <div class="item_slider" data-swiper-wrap="">
#       <div class="slider_images swiper-wrapper">
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Əhmədli m. - 64 m²" class="lazyload" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F02%2F23%2F51%2F59%2F98c7c363-4e31-4742-a3f6-fbeb1267f3a7%2F83821_olQt-9SpNG92DfXmLtrOPA.jpg" src="..."/>
#        </div>
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Əhmədli m. - 64 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F02%2F23%2F51%2F58%2Fa6819d28-99c8-4dc8-8107-528b7e1cb2ea%2F83837_ft13OwN24gCJkv0DlR82Uw.jpg" src="..."/>
#        </div>
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Əhmədli m. - 64 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F02%2F23%2F51%2F59%2Fdfc31162-5f0d-44f0-9f58-3c9fd418e79b%2F10784_ck2570q9dABfKMHMeamHHw.jpg" src="..."/>
#        </div>
#        <div class="slider_image slider_more-images-block swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Əhmədli m. - 64 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F02%2F23%2F51%2F59%2F69ce5f70-f965-4222-9c2d-cab03df67666%2F83790_i-ll0-MYVh1PohH0B7r3tg.jpg" src="..."/>
#         <div class="slider_more-images">
#          Daha 21 şəklə bax
#         </div>
#        </div>
#       </div>
#       <div class="swiper-lazy-preloader">
#       </div>
#       <a class="slider_controls" href="/items/2820516" target="_blank">
#        <div class="swiper-button swiper-button-prev">
#        </div>
#        <div class="swiper-button swiper-button-next">
#        </div>
#       </a>
#      </div>
#      <div class="bill_of_sale">
#       <a class="item_link" href="/items/2820516" target="_blank">
#       </a>
#       <span>
#        Kupça var
#       </span>
#      </div>
#      <div class="mortgage">
#       <a class="item_link" href="/items/2820516" target="_blank">
#       </a>
#       <span>
#        İpoteka var
#       </span>
#      </div>
#      <div class="products-paid">
#       <span class="featured-icon">
#       </span>
#       <span class="vipped-icon">
#       </span>
#      </div>
#      <div class="products-label">
#       Agentlik
#      </div>
#     </div>
#     <div class="card_params">
#      <div class="abs_block">
#       <div class="price">
#        <span class="price-val">
#         82 000
#        </span>
#        <span class="price-cur">
#         AZN
#        </span>
#       </div>
#      </div>
#      <div class="location">
#       Əhmədli m.
#      </div>
#      <ul class="name">
#       <li>
#        2 otaqlı
#       </li>
#       <li>
#        64 m²
#       </li>
#       <li>
#        3/19 mərtəbə
#       </li>
#      </ul>
#      <div class="card_footer">
#       <div class="city_when">
#        Bakı, 07 i̇yun 2022
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="items-i vipped">
#     <a class="item_link" href="/items/2821492" target="_blank">
#     </a>
#     <div class="bookmarking card_view">
#      <a class="add_bookmark" data-disable="true" data-method="post" data-remote="true" href="/bookmarks?card_view=true&amp;item_id=2821492" rel="nofollow">
#      </a>
#     </div>
#     <div class="preview">
#      <div class="item_slider" data-swiper-wrap="">
#       <div class="slider_images swiper-wrapper">
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Nərimanov r. - 70.2 m²" class="lazyload" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F04%2F13%2F42%2F28%2F784b3019-40e6-48fe-a1c8-4c6f7c8bd655%2F10808_28gUplKBigjx5MLBcmqNVQ.jpg" src="..."/>
#        </div>
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Nərimanov r. - 70.2 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F03%2F15%2F28%2F25%2Fe5ea77f6-73ae-41f6-b95e-89d47c2d867f%2F38472_7zVRZ5wcSRo7ySICJu82Bg.jpg" src="..."/>
#        </div>
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Nərimanov r. - 70.2 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F03%2F15%2F28%2F25%2Ff792e921-9f28-4de3-9ee0-62da368d1743%2F38483_kmEfKkl8keG3rWW9f0HTOg.jpg" src="..."/>
#        </div>
#        <div class="slider_image slider_more-images-block swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Nərimanov r. - 70.2 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F03%2F15%2F28%2F25%2Fafc96a77-12fa-4179-b63d-5d78e665447d%2F38483_P8yEeDJ6OXl6vMAPr4WcMA.jpg" src="..."/>
#         <div class="slider_more-images">
#          Daha 2 şəklə bax
#         </div>
#        </div>
#       </div>
#       <div class="swiper-lazy-preloader">
#       </div>
#       <a class="slider_controls" href="/items/2821492" target="_blank">
#        <div class="swiper-button swiper-button-prev">
#        </div>
#        <div class="swiper-button swiper-button-next">
#        </div>
#       </a>
#      </div>
#      <div class="bill_of_sale">
#       <a class="item_link" href="/items/2821492" target="_blank">
#       </a>
#       <span>
#        Kupça var
#       </span>
#      </div>
#      <div class="products-paid">
#       <span class="featured-icon">
#       </span>
#       <span class="vipped-icon">
#       </span>
#      </div>
#     </div>
#     <div class="card_params">
#      <div class="abs_block">
#       <div class="price">
#        <span class="price-val">
#         119 340
#        </span>
#        <span class="price-cur">
#         AZN
#        </span>
#       </div>
#      </div>
#      <div class="location">
#       Nərimanov r.
#      </div>
#      <ul class="name">
#       <li>
#        2 otaqlı
#       </li>
#       <li>
#        70.2 m²
#       </li>
#       <li>
#        8/14 mərtəbə
#       </li>
#      </ul>
#      <div class="card_footer">
#       <div class="city_when">
#        Bakı, 04 i̇yun 2022
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="items-i vipped">
#     <a class="item_link" href="/items/2840401" target="_blank">
#     </a>
#     <div class="bookmarking card_view">
#      <a class="add_bookmark" data-disable="true" data-method="post" data-remote="true" href="/bookmarks?card_view=true&amp;item_id=2840401" rel="nofollow">
#      </a>
#     </div>
#     <div class="preview">
#      <div class="item_slider" data-swiper-wrap="">
#       <div class="slider_images swiper-wrapper">
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Əhmədli m. - 63 m²" class="lazyload" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F14%2F15%2F32%2F52%2F610dafbb-1ddf-4794-aeec-76ec494368de%2F23204_ge2jp5ruSn9eo3dX5FP1Kw.jpg" src="..."/>
#        </div>
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Əhmədli m. - 63 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F14%2F15%2F32%2F58%2F90d1354a-0a0d-4565-be06-9a6ae443d357%2F23207_HTvWE4QDG5X1V2AcMd-hrA.jpg" src="..."/>
#        </div>
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Əhmədli m. - 63 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F14%2F15%2F32%2F57%2Fc079a854-9659-45a0-bf3f-5eb9872ca524%2F23170_XCiaGYjVCfY0DOBEdjZqmA.jpg" src="..."/>
#        </div>
#        <div class="slider_image slider_more-images-block swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Əhmədli m. - 63 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F14%2F15%2F32%2F58%2Fcf493c58-e4c0-4ce7-8783-8a1daed8ae63%2F23197_WKpzcxHjrAzNzijE4e9ntQ.jpg" src="..."/>
#         <div class="slider_more-images">
#          Daha 14 şəklə bax
#         </div>
#        </div>
#       </div>
#       <div class="swiper-lazy-preloader">
#       </div>
#       <a class="slider_controls" href="/items/2840401" target="_blank">
#        <div class="swiper-button swiper-button-prev">
#        </div>
#        <div class="swiper-button swiper-button-next">
#        </div>
#       </a>
#      </div>
#      <div class="bill_of_sale">
#       <a class="item_link" href="/items/2840401" target="_blank">
#       </a>
#       <span>
#        Kupça var
#       </span>
#      </div>
#      <div class="products-paid">
#       <span class="featured-icon">
#       </span>
#       <span class="vipped-icon">
#       </span>
#      </div>
#     </div>
#     <div class="card_params">
#      <div class="abs_block">
#       <div class="price">
#        <span class="price-val">
#         80 000
#        </span>
#        <span class="price-cur">
#         AZN
#        </span>
#       </div>
#      </div>
#      <div class="location">
#       Əhmədli m.
#      </div>
#      <ul class="name">
#       <li>
#        2 otaqlı
#       </li>
#       <li>
#        63 m²
#       </li>
#       <li>
#        11/16 mərtəbə
#       </li>
#      </ul>
#      <div class="card_footer">
#       <div class="city_when">
#        Bakı, dünən 15:48
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="items-i featured vipped">
#     <a class="item_link" href="/items/2533624" target="_blank">
#     </a>
#     <div class="bookmarking card_view">
#      <a class="add_bookmark" data-disable="true" data-method="post" data-remote="true" href="/bookmarks?card_view=true&amp;item_id=2533624" rel="nofollow">
#      </a>
#     </div>
#     <div class="preview">
#      <div class="item_slider" data-swiper-wrap="">
#       <div class="slider_images swiper-wrapper">
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - 7-ci mikrorayon q. - 80.4 m²" class="lazyload" data-src="https://bina.azstatic.com/uploads/f460x345/2021%2F12%2F27%2F17%2F26%2F53%2Ff25b1ab5-935b-403b-a0a4-d223978441d3%2F37434_SttApC8KWIlicAP7jFuuqQ.jpg" src="..."/>
#        </div>
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - 7-ci mikrorayon q. - 80.4 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2021%2F12%2F27%2F17%2F26%2F56%2F2511e094-9e9b-47a6-af30-8765573d8ad3%2F60556_gnv9zWYvNpxzhFlE6D3_zw.jpg" src="..."/>
#        </div>
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - 7-ci mikrorayon q. - 80.4 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2021%2F12%2F27%2F17%2F27%2F00%2F8cd2e0d6-4bf8-47b4-a857-cfe74c1991fa%2F60433_nZEgEjRf-xMS1bWXJoXItw.jpg" src="..."/>
#        </div>
#        <div class="slider_image slider_more-images-block swiper-slide">
#         <img alt="2 otaqlı yeni tikili - 7-ci mikrorayon q. - 80.4 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2021%2F12%2F27%2F17%2F27%2F03%2Fe9ad34a1-8ad2-467d-9270-0b0291c1aced%2F72030_L9L1sJib1trNA4dlLVyQ-g.jpg" src="..."/>
#         <div class="slider_more-images">
#          Daha 1 şəklə bax
#         </div>
#        </div>
#       </div>
#       <div class="swiper-lazy-preloader">
#       </div>
#       <a class="slider_controls" href="/items/2533624" target="_blank">
#        <div class="swiper-button swiper-button-prev">
#        </div>
#        <div class="swiper-button swiper-button-next">
#        </div>
#       </a>
#      </div>
#      <div class="products-paid">
#       <span class="featured-icon">
#       </span>
#       <span class="vipped-icon">
#       </span>
#      </div>
#      <div class="products-label">
#       Agentlik
#      </div>
#     </div>
#     <div class="card_params">
#      <div class="abs_block">
#       <div class="price">
#        <span class="price-val">
#         100 500
#        </span>
#        <span class="price-cur">
#         AZN
#        </span>
#       </div>
#      </div>
#      <div class="location">
#       7-ci mikrorayon q.
#      </div>
#      <ul class="name">
#       <li>
#        2 otaqlı
#       </li>
#       <li>
#        80.4 m²
#       </li>
#       <li>
#        9/16 mərtəbə
#       </li>
#      </ul>
#      <div class="card_footer">
#       <div class="city_when">
#        Bakı, dünən 15:16
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </section>
#  <div class="reveal-modal modal-ad-select" id="vipped_modal">
#   <div class="reveal-header">
#    Sizin elanınızın nömrəsi
#   </div>
#   <div class="reveal-content">
#    <form>
#     <input id="vip_ad_number" type="text"/>
#     <button id="vip_ad_number_submit">
#      →
#     </button>
#    </form>
#   </div>
#   <span class="close-reveal-modal">
#    ×
#   </span>
#  </div>
#  <section class="vipped_row thumblist row vipped-apartments">
#   <header class="section-header">
#    <div class="thumblist-title">
#     Yaşayış komplekslərinin VIP elanları
#    </div>
#   </header>
#   <div class="items_list items">
#    <div class="items-i featured vipped">
#     <a class="item_link" href="/yasayis-kompleksleri/220" target="_blank">
#     </a>
#     <div class="bookmarking card_view">
#      <a class="add_bookmark" data-disable="true" data-method="post" data-remote="true" href="/bookmarks?card_view=true&amp;item_id=2469697" rel="nofollow">
#      </a>
#     </div>
#     <div class="preview">
#      <div class="item_slider" data-swiper-wrap="">
#       <div class="slider_images swiper-wrapper">
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Yasamal r. - 74.3 m²" class="lazyload" data-src="https://bina.azstatic.com/uploads/f460x345/2021%2F11%2F22%2F14%2F50%2F59%2Fe97bf5db-9235-4340-bd3b-268c56ee3364%2F58996_KKRnUY3Uee7rH1MP5OG_pQ.jpg" src="..."/>
#        </div>
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Yasamal r. - 74.3 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2021%2F11%2F22%2F14%2F51%2F01%2Fb1f3448a-3c72-4612-8891-2c474bf0693f%2F58983_SOh1hok4Bxk2xTp7vrw2aQ.jpg" src="..."/>
#        </div>
#        <div class="slider_image swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Yasamal r. - 74.3 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2021%2F11%2F22%2F14%2F50%2F59%2Fd5f5c62f-3231-457d-aac1-710ec1620a91%2F58996_YJaJ9-tcnA9vqE1Oyy2K3w.jpg" src="..."/>
#        </div>
#        <div class="slider_image slider_more-images-block swiper-slide">
#         <img alt="2 otaqlı yeni tikili -
m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2018%2F10%2F23%2F10%2F00%2F18%2Fd4fc2fdc-f448-4aae-8583-017ee798967b%2F47898_m56KpSeyBvk-onQo-E7KsA.jpg" src="..."/>
#        </div>
#        <div class="slider_image slider_more-images-block swiper-slide">
#         <img alt="2 otaqlı yeni tikili - Gənclik m. - 102.5 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2018%2F10%2F23%2F10%2F00%2F07%2F53b053a1-d6ac-47ff-849f-163b5eca2161%2F55122_j_8z4ptCSb-XQMmdegoApw.jpg" src="..."/>
#         <div class="slider_more-images">
#          Daha 2 şəklə bax
#         </div>
#        </div>
#       </div>
#       <div class="swiper-lazy-preloader">
#       </div>
#       <a class="slider_controls" href="/yasayis-kompleksleri/82" target="_blank">
#        <div class="swiper-button swiper-button-prev">
#        </div>
#        <div class="swiper-button swiper-button-next">
#        </div>
#       </a>
#      </div>
#      <div class="products-paid">
#       <span class="featured-icon">
#       </span>
#       <span class="vipped-icon">
#       </span>
#      </div>
#      <div class="products-label residence">
#       Kompleks
#      </div>
#     </div>
#     <div class="card_params">
#      <div class="abs_block">
#       <div class="price">
#        <span class="price-val">
#         184 428
#        </span>
#        <span class="price-cur">
#         AZN
#        </span>
#       </div>
#      </div>
#      <div class="location">
#       Gənclik m.
#      </div>
#      <ul class="name">
#       <li>
#        2 otaqlı
#       </li>
#       <li>
#        102.5 m²
#       </li>
#      </ul>
#      <div class="card_footer">
#       <div class="city_when">
#        Bakı, 13 i̇yun 2022
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </section>
#  <header class="section-header">
#   <div class="thumblist-title">
#    ELANLAR
#   </div>
#  </header>
#  <div class="items_list">
#   <div class="items-i" data-item-id="2780238">
#    <a class="item_link" href="/items/2780238" target="_blank">
#    </a>
#    <div class="bookmarking card_view">
#     <a class="add_bookmark" data-disable="true" data-method="post" data-remote="true" href="/bookmarks?card_view=true&amp;item_id=2780238" rel="nofollow">
#     </a>
#    </div>
#    <div class="preview">
#     <div class="item_slider" data-swiper-wrap="">
#      <div class="slider_images swiper-wrapper">
#       <div class="slider_image swiper-slide">
#        <img alt="2 otaqlı yeni tikili - Həzi Aslanov m. - 68 m²" class="lazyload" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F05%2F13%2F00%2F46%2F56%2Fa776fa2f-c80b-4033-8b35-2493ab8e4f25%2F38492_HH_eR3KozqlE4kayE7gp4w.jpg" src="..."/>
#       </div>
#       <div class="slider_image swiper-slide">
#        <img alt="2 otaqlı yeni tikili - Həzi Aslanov m. - 68 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F05%2F13%2F00%2F47%2F03%2F41fdd4b7-0b21-4c78-899f-42f84535b57d%2F38441_TA3X-8nkPn1JKpHGoCPl_A.jpg" src="..."/>
#       </div>
#       <div class="slider_image swiper-slide">
#        <img alt="2 otaqlı yeni tikili - Həzi Aslanov m. - 68 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F05%2F13%2F00%2F46%2F56%2F941663bb-3a33-4ffc-941d-d688d8abe3e6%2F38464_tWEY_UW7BHPvvl4vDjOOFA.jpg" src="..."/>
#       </div>
#       <div class="slider_image slider_more-images-block swiper-slide">
#        <img alt="2 otaqlı yeni tikili - Həzi Aslanov m. - 68 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F05%2F13%2F00%2F46%2F57%2Fe3dc02c9-0740-4575-9e46-84496e51f931%2F38492_a-u-wSxrWLBBVAf5Ik55OA.jpg" src="..."/>
#        <div class="slider_more-images">
#         Daha 23 şəklə bax
#        </div>
#       </div>
#      </div>
#      <div class="swiper-lazy-preloader">
#      </div>
#      <a class="slider_controls" href="/items/2780238" target="_blank">
#       <div class="swiper-button swiper-button-prev">
#       </div>
#       <div class="swiper-button swiper-button-next">
#       </div>
#      </a>
#     </div>
#     <div class="bill_of_sale">
#      <a class="item_link" href="/items/2780238" target="_blank">
#      </a>
#      <span>
#       Kupça var
#      </span>
#     </div>
#     <div class="mortgage">
#      <a class="item_link" href="/items/2780238" target="_blank">
#      </a>
#      <span>
#       İpoteka var
#      </span>
#     </div>
#     <div class="products-paid">
#      <span class="featured-icon">
#      </span>
#      <span class="vipped-icon">
#      </span>
#     </div>
#    </div>
#    <div class="card_params">
#     <div class="abs_block">
#      <div class="price">
#       <span class="price-val">
#        113 500
#       </span>
#       <span class="price-cur">
#        AZN
#       </span>
#      </div>
#     </div>
#     <div class="location">
#      Həzi Aslanov m.
#     </div>
#     <ul class="name">
#      <li>
#       2 otaqlı
#      </li>
#      <li>
#       68 m²
#      </li>
#      <li>
#       10/14 mərtəbə
#      </li>
#     </ul>
#     <div class="card_footer">
#      <div class="city_when">
#       Bakı, bugün 01:26
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="items-i" data-item-id="2841343">
#    <a class="item_link" href="/items/2841343" target="_blank">
#    </a>
#    <div class="bookmarking card_view">
#     <a class="add_bookmark" data-disable="true" data-method="post" data-remote="true" href="/bookmarks?card_view=true&amp;item_id=2841343" rel="nofollow">
#     </a>
#    </div>
#    <div class="preview">
#     <div class="item_slider" data-swiper-wrap="">
#      <div class="slider_images swiper-wrapper">
#       <div class="slider_image swiper-slide">
#        <img alt="2 otaqlı yeni tikili - Nizami m. - 91 m²" class="lazyload" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F15%2F00%2F50%2F22%2F9616a68e-60be-4ba2-a262-80a8aac28b88%2F23205_WClu-CK0tKJ1k6B1_Q2Ycw.jpg" src="..."/>
#       </div>
#       <div class="slider_image swiper-slide">
#        <img alt="2 otaqlı yeni tikili - Nizami m. - 91 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F15%2F00%2F50%2F22%2F88115791-98b2-455d-ab6c-e918fe227191%2F23183_kvkr7M6uYR46r60AWHDydQ.jpg" src="..."/>
#       </div>
#       <div class="slider_image swiper-slide">
#        <img alt="2 otaqlı yeni tikili - Nizami m. - 91 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F15%2F00%2F50%2F22%2Fd64ad8b1-c5ed-4e9e-83cc-3ff57e246251%2F23209__koDikSoZzSp6CBSDxH6vQ.jpg" src="..."/>
#       </div>
#       <div class="slider_image slider_more-images-block swiper-slide">
#        <img alt="2 otaqlı yeni tikili - Nizami m. - 91 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F06%2F15%2F00%2
#       <div class="slider_image swiper-slide">
#        <img alt="2 otaqlı yeni tikili - İnşaatçılar m. - 54 m²" class="lazyload" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F05%2F25%2F23%2F16%2F59%2F101093d9-a593-481a-839f-533480d2ae6d%2F83806_dP4dB5mFoXEIHNn8-1OMeQ.jpg" src="..."/>
#       </div>
#       <div class="slider_image swiper-slide">
#        <img alt="2 otaqlı yeni tikili - İnşaatçılar m. - 54 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F05%2F25%2F23%2F17%2F02%2F4d175e3e-1117-4aa8-a584-53029768b450%2F38453_ZaY18MKe5I4-lTMueL7eJg.jpg" src="..."/>
#       </div>
#       <div class="slider_image swiper-slide">
#        <img alt="2 otaqlı yeni tikili - İnşaatçılar m. - 54 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F05%2F25%2F23%2F17%2F02%2Fc8ef6402-dfa9-4fca-a0d5-4080f5ca7c37%2F38444_HxIp8TH3TmfVKGR6ttWoAA.jpg" src="..."/>
#       </div>
#       <div class="slider_image slider_more-images-block swiper-slide">
#        <img alt="2 otaqlı yeni tikili - İnşaatçılar m. - 54 m²" class="swiper-lazy" data-src="https://bina.azstatic.com/uploads/f460x345/2022%2F05%2F25%2F23%2F17%2F01%2F37925e44-0729-4cf9-96c1-7ef75dcf21ff%2F83821_UkbTNcSF9N_rVvcf9Ono4Q.jpg" src="..."/>
#        <div class="slider_more-images">
#         Daha 15 şəklə bax
#        </div>
#       </div>
#      </div>
#      <div class="swiper-lazy-preloader">
#      </div>
#      <a class="slider_controls" href="/items/2807011" target="_blank">
#       <div class="swiper-button swiper-button-prev">
#       </div>
#       <div class="swiper-button swiper-button-next">
#       </div>
#      </a>
#     </div>
#     <div class="bill_of_sale">
#      <a class="item_link" href="/items/2807011" target="_blank">
#      </a>
#      <span>
#       Kupça var
#      </span>
#     </div>
#     <div class="products-paid">
#      <span class="featured-icon">
#      </span>
#      <span class="vipped-icon">
#      </span>
#     </div>
#    </div>
#    <div class="card_params">
#     <div class="abs_block">
#      <div class="price">
#       <span class="price-val">
#        93 500
#       </span>
#       <span class="price-cur">
#        AZN
#       </span>
#      </div>
#     </div>
#     <div class="location">
#      İnşaatçılar m.
#     </div>
#     <ul class="name">
#      <li>
#       2 otaqlı
#      </li>
#      <li>
#       54 m²
#      </li>
#      <li>
#       13/18 mərtəbə
#      </li>
#     </ul>
#     <div class="card_footer">
#      <div class="city_when">
#       Bakı, dünən 21:59
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="bottom_pagination">
#   <nav class="pagination">
#    <div class="pagination-inner">
#     <span class="page current">
#      1
#     </span>
#     <span class="page">
#      <a data-remote="true" href="/baki/alqi-satqi/menziller/yeni-tikili/2-otaqli?items_view=list&amp;page=2" rel="next">
#       2
#      </a>
#     </span>
#     <span class="page">
#      <a data-remote="true" href="/baki/alqi-satqi/menziller/yeni-tikili/2-otaqli?items_view=list&amp;page=3">
#       3
#      </a>
#     </span>
#     <span class="page">
#      <a data-remote="true" href="/baki/alqi-satqi/menziller/yeni-tikili/2-otaqli?items_view=list&amp;page=4">
#       4
#      </a>
#     </span>
#     <span class="page">
#      <a data-remote="true" href="/baki/alqi-satqi/menziller/yeni-tikili/2-otaqli?items_view=list&amp;page=5">
#       5
#      </a>
#     </span>
#     <span class="next">
#      <a data-remote="true" href="/baki/alqi-satqi/menziller/yeni-tikili/2-otaqli?items_view=list&amp;page=2" rel="next">
#       Növbəti
#      </a>
#     </span>
#    </div>
#   </nav>
#  </div>
#  <div class="page-loader-bg">
#  </div>
# </div>

# %%
job_elements = results.find_all("div", class_="card_params")

# %%
for job_element in job_elements:
    print(job_element, end="\n"*2)
# Out:
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">82 000</span><span class="price-cur">AZN</span></div></div><div class="location">Əhmədli m.</div><ul class="name"><li>2 otaqlı</li><li>64 m²</li><li>3/19 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, 07 i̇yun 2022</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">119 340</span><span class="price-cur">AZN</span></div></div><div class="location">Nərimanov r.</div><ul class="name"><li>2 otaqlı</li><li>70.2 m²</li><li>8/14 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, 04 i̇yun 2022</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">80 000</span><span class="price-cur">AZN</span></div></div><div class="location">Əhmədli m.</div><ul class="name"><li>2 otaqlı</li><li>63 m²</li><li>11/16 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 15:48</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">100 500</span><span class="price-cur">AZN</span></div></div><div class="location">7-ci mikrorayon q.</div><ul class="name"><li>2 otaqlı</li><li>80.4 m²</li><li>9/16 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 15:16</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">104 777</span><span class="price-cur">AZN</span></div></div><div class="location">Yasamal r.</div><ul class="name"><li>2 otaqlı</li><li>74.3 m²</li></ul><div class="card_footer"><div class="city_when">Bakı, 31 may 2022</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">180 638</span><span class="price-cur">AZN</span></div></div><div class="location">Bakı</div><ul class="name"><li>2 otaqlı</li><li>73.7 m²</li></ul><div class="card_footer"><div class="city_when">Bakı, 09 i̇yun 2022</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">260 474</span><span class="price-cur">AZN</span></div></div><div class="location">Sea Breeze </div><ul class="name"><li>2 otaqlı</li><li>65.2 m²</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 14:47</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">184 428</span><span class="price-cur">AZN</span></div></div><div class="location">Gənclik m.</div><ul class="name"><li>2 otaqlı</li><li>102.5 m²</li></ul><div class="card_footer"><div class="city_when">Bakı, 13 i̇yun 2022</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">113 500</span><span class="price-cur">AZN</span></div></div><div class="location">Həzi Aslanov m.</div><ul class="name"><li>2 otaqlı</li><li>68 m²</li><li>10/14 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, bugün 01:26</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">191 000</span><span class="price-cur">AZN</span></div></div><div class="location">Nizami m.</div><ul class="name"><li>2 otaqlı</li><li>91 m²</li><li>4/18 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, bugün 00:53</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">25 000</span><span class="price-cur">AZN</span></div></div><div class="location">Hövsan q.</div><ul class="name"><li>2 otaqlı</li><li>58 m²</li><li>1/7 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, bugün 00:30</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">90 000</span><span class="price-cur">AZN</span></div></div><div class="location">20 Yanvar m.</div><ul class="name"><li>2 otaqlı</li><li>44 m²</li><li>17/20 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, bugün 00:24</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">76 000</span><span class="price-cur">AZN</span></div></div><div class="location">9-cu mikrorayon q.</div><ul class="name"><li>2 otaqlı</li><li>48 m²</li><li>2/18 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, bugün 00:00</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">130 000</span><span class="price-cur">AZN</span></div></div><div class="location">İnşaatçılar m.</div><ul class="name"><li>2 otaqlı</li><li>70 m²</li><li>12/12 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 23:57</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">99 000</span><span class="price-cur">AZN</span></div></div><div class="location">Əhmədli m.</div><ul class="name"><li>2 otaqlı</li><li>70 m²</li><li>7/17 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 23:48</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">129 900</span><span class="price-cur">AZN</span></div></div><div class="location">Xətai r.</div><ul class="name"><li>2 otaqlı</li><li>118 m²</li><li>11/17 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 23:46</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">124 000</span><span class="price-cur">AZN</span></div></div><div class="location">Nəsimi r.</div><ul class="name"><li>2 otaqlı</li><li>82 m²</li><li>16/20 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 23:41</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">89 000</span><span class="price-cur">AZN</span></div></div><div class="location">Əhmədli m.</div><ul class="name"><li>2 otaqlı</li><li>72 m²</li><li>7/20 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 23:41</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">145 000</span><span class="price-cur">AZN</span></div></div><div class="location">İnşaatçılar m.</div><ul class="name"><li>2 otaqlı</li><li>93 m²</li><li>20/20 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 23:33</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">102 000</span><span class="price-cur">AZN</span></div></div><div class="location">Memar Əcəmi m.</div><ul class="name"><li>2 otaqlı</li><li>60 m²</li><li>14/17 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 23:28</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">270 000</span><span class="price-cur">AZN</span></div></div><div class="location">Nardaran q.</div><ul class="name"><li>2 otaqlı</li><li>81 m²</li><li>3/7 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 23:19</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">86 000</span><span class="price-cur">AZN</span></div></div><div class="location">İnşaatçılar m.</div><ul class="name"><li>2 otaqlı</li><li>48 m²</li><li>2/18 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 23:18</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">169 999</span><span class="price-cur">AZN</span></div></div><div class="location">Elmlər Akademiyası m.</div><ul class="name"><li>2 otaqlı</li><li>100 m²</li><li>12/17 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 22:59</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">170 000</span><span class="price-cur">AZN</span></div></div><div class="location">Elmlər Akademiyası m.</div><ul class="name"><li>2 otaqlı</li><li>55 m²</li><li>14/17 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 22:58</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">139 000</span><span class="price-cur">AZN</span></div></div><div class="location">8 Noyabr m.</div><ul class="name"><li>2 otaqlı</li><li>95 m²</li><li>13/13 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 22:56</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">119 900</span><span class="price-cur">AZN</span></div></div><div class="location">Qara Qarayev m.</div><ul class="name"><li>2 otaqlı</li><li>71 m²</li><li>16/17 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 22:44</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">135 000</span><span class="price-cur">AZN</span></div></div><div class="location">4-cü mikrorayon q.</div><ul class="name"><li>2 otaqlı</li><li>87 m²</li><li>16/18 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 22:33</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">260 000</span><span class="price-cur">AZN</span></div></div><div class="location">Nizami m.</div><ul class="name"><li>2 otaqlı</li><li>110 m²</li><li>8/17 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 22:23</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">62 000</span><span class="price-cur">AZN</span></div></div><div class="location">Masazır q.</div><ul class="name"><li>2 otaqlı</li><li>82 m²</li><li>6/6 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 22:19</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">185 000</span><span class="price-cur">AZN</span></div></div><div class="location">Nəriman Nərimanov m.</div><ul class="name"><li>2 otaqlı</li><li>90 m²</li><li>5/14 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 22:16</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">180 000</span><span class="price-cur">AZN</span></div></div><div class="location">Yasamal q.</div><ul class="name"><li>2 otaqlı</li><li>100 m²</li><li>20/27 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 22:01</div></div></div>
#
# <div class="card_params"><div class="abs_block"><div class="price"><span class="price-val">93 500</span><span class="price-cur">AZN</span></div></div><div class="location">İnşaatçılar m.</div><ul class="name"><li>2 otaqlı</li><li>54 m²</li><li>13/18 mərtəbə</li></ul><div class="card_footer"><div class="city_when">Bakı, dünən 21:59</div></div></div>

# %%
prices=[] #List to store name of the product
locations=[] #List to store price of the product
names=[] #List to store rating of the product
dates_posted=[] 


for job_element in job_elements:
    
    name = job_element.find("ul", class_="name")
    location = job_element.find(class_="location")
    price = job_element.find("span", class_="price-val")
    date_posted = job_element.find(class_="city_when")
    
    names.append(name.text)
    locations.append(location.text)
    prices.append(price.text)
    dates_posted.append(date_posted.text)

# %%
df = pd.DataFrame({'Name': names, 'Price':prices,'Location':locations, 'Date':dates_posted, 'Today': datetime.today().
                   strftime('%m/%d/%Y')})

# %%
df
# Out:
#                            Name    Price               Location  \
# 0     2 otaqlı64 m²3/19 mərtəbə   82 000             Əhmədli m.
# 1   2 otaqlı70.2 m²8/14 mərtəbə  119 340           Nərimanov r.
# 2    2 otaqlı63 m²11/16 mərtəbə   80 000             Əhmədli m.
# 3   2 otaqlı80.4 m²9/16 mərtəbə  100 500     7-ci mikrorayon q.
# 4               2 otaqlı74.3 m²  104 777             Yasamal r.
# 5               2 otaqlı73.7 m²  180 638                   Bakı
# 6               2 otaqlı65.2 m²  260 474            Sea Breeze
# 7              2 otaqlı102.5 m²  184 428             Gənclik m.
# 8    2 otaqlı68 m²10/14 mərtəbə  113 500        Həzi Aslanov m.
# 9     2 otaqlı91 m²4/18 mərtəbə  191 000              Nizami m.
# 10     2 otaqlı58 m²1/7 mərtəbə   25 000              Hövsan q.
# 11   2 otaqlı44 m²17/20 mərtəbə   90 000           20 Yanvar m.
# 12    2 otaqlı48 m²2/18 mərtəbə   76 000     9-cu mikrorayon q.
# 13   2 otaqlı70 m²12/12 mərtəbə  130 000         İnşaatçılar m.
# 14    2 otaqlı70 m²7/17 mərtəbə   99 000             Əhmədli m.
# 15  2 otaqlı118 m²11/17 mərtəbə  129 900               Xətai r.
# 16   2 otaqlı82 m²16/20 mərtəbə  124 000              Nəsimi r.
# 17    2 otaqlı72 m²7/20 mərtəbə   89 000             Əhmədli m.
# 18   2 otaqlı93 m²20/20 mərtəbə  145 000         İnşaatçılar m.
# 19   2 otaqlı60 m²14/17 mərtəbə  102 000         Memar Əcəmi m.
# 20     2 otaqlı81 m²3/7 mərtəbə  270 000            Nardaran q.
# 21    2 otaqlı48 m²2/18 mərtəbə   86 000         İnşaatçılar m.
# 22  2 otaqlı100 m²12/17 mərtəbə  169 999  Elmlər Akademiyası m.
# 23   2 otaqlı55 m²14/17 mərtəbə  170 000  Elmlər Akademiyası m.
# 24   2 otaqlı95 m²13/13 mərtəbə  139 000            8 Noyabr m.
# 25   2 otaqlı71 m²16/17 mərtəbə  119 900        Qara Qarayev m.
# 26   2 otaqlı87 m²16/18 mərtəbə  135 000     4-cü mikrorayon q.
# 27   2 otaqlı110 m²8/17 mərtəbə  260 000              Nizami m.
# 28     2 otaqlı82 m²6/6 mərtəbə   62 000             Masazır q.
# 29    2 otaqlı90 m²5/14 mərtəbə  185 000   Nəriman Nərimanov m.
# 30  2 otaqlı100 m²20/27 mərtəbə  180 000             Yasamal q.
# 31   2 otaqlı54 m²13/18 mərtəbə   93 500         İnşaatçılar m.
#
#                    Date       Today
# 0   Bakı, 07 i̇yun 2022  06/14/2022
# 1   Bakı, 04 i̇yun 2022  06/14/2022
# 2     Bakı, dünən 15:48  06/14/2022
# 3     Bakı, dünən 15:16  06/14/2022
# 4     Bakı, 31 may 2022  06/14/2022
# 5   Bakı, 09 i̇yun 2022  06/14/2022
# 6     Bakı, dünən 14:47  06/14/2022
# 7   Bakı, 13 i̇yun 2022  06/14/2022
# 8     Bakı, bugün 01:26  06/14/2022
# 9     Bakı, bugün 00:53  06/14/2022
# 10    Bakı, bugün 00:30  06/14/2022
# 11    Bakı, bugün 00:24  06/14/2022
# 12    Bakı, bugün 00:00  06/14/2022
# 13    Bakı, dünən 23:57  06/14/2022
# 14    Bakı, dünən 23:48  06/14/2022
# 15    Bakı, dünən 23:46  06/14/2022
# 16    Bakı, dünən 23:41  06/14/2022
# 17    Bakı, dünən 23:41  06/14/2022
# 18    Bakı, dünən 23:33  06/14/2022
# 19    Bakı, dünən 23:28  06/14/2022
# 20    Bakı, dünən 23:19  06/14/2022
# 21    Bakı, dünən 23:18  06/14/2022
# 22    Bakı, dünən 22:59  06/14/2022
# 23    Bakı, dünən 22:58  06/14/2022
# 24    Bakı, dünən 22:56  06/14/2022
# 25    Bakı, dünən 22:44  06/14/2022
# 26    Bakı, dünən 22:33  06/14/2022
# 27    Bakı, dünən 22:23  06/14/2022
# 28    Bakı, dünən 22:19  06/14/2022
# 29    Bakı, dünən 22:16  06/14/2022
# 30    Bakı, dünən 22:01  06/14/2022
# 31    Bakı, dünən 21:59  06/14/2022

# %%
df['num_rooms'] = df['Name'].str.split('otaqlı', 1, expand=True)[0]

df['size'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[0]

df['floor'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[1].\
str.split('mərtəbə', 1, expand=True)[0]

# %%
df_1 = df[['num_rooms', 'size', 'floor', 'Price', 'Location', 'Date', 'Today']]

# %%
df_1
# Out:
#    num_rooms    size   floor    Price               Location  \
# 0         2      64    3/19    82 000             Əhmədli m.
# 1         2    70.2    8/14   119 340           Nərimanov r.
# 2         2      63   11/16    80 000             Əhmədli m.
# 3         2    80.4    9/16   100 500     7-ci mikrorayon q.
# 4         2    74.3           104 777             Yasamal r.
# 5         2    73.7           180 638                   Bakı
# 6         2    65.2           260 474            Sea Breeze
# 7         2   102.5           184 428             Gənclik m.
# 8         2      68   10/14   113 500        Həzi Aslanov m.
# 9         2      91    4/18   191 000              Nizami m.
# 10        2      58     1/7    25 000              Hövsan q.
# 11        2      44   17/20    90 000           20 Yanvar m.
# 12        2      48    2/18    76 000     9-cu mikrorayon q.
# 13        2      70   12/12   130 000         İnşaatçılar m.
# 14        2      70    7/17    99 000             Əhmədli m.
# 15        2     118   11/17   129 900               Xətai r.
# 16        2      82   16/20   124 000              Nəsimi r.
# 17        2      72    7/20    89 000             Əhmədli m.
# 18        2      93   20/20   145 000         İnşaatçılar m.
# 19        2      60   14/17   102 000         Memar Əcəmi m.
# 20        2      81     3/7   270 000            Nardaran q.
# 21        2      48    2/18    86 000         İnşaatçılar m.
# 22        2     100   12/17   169 999  Elmlər Akademiyası m.
# 23        2      55   14/17   170 000  Elmlər Akademiyası m.
# 24        2      95   13/13   139 000            8 Noyabr m.
# 25        2      71   16/17   119 900        Qara Qarayev m.
# 26        2      87   16/18   135 000     4-cü mikrorayon q.
# 27        2     110    8/17   260 000              Nizami m.
# 28        2      82     6/6    62 000             Masazır q.
# 29        2      90    5/14   185 000   Nəriman Nərimanov m.
# 30        2     100   20/27   180 000             Yasamal q.
# 31        2      54   13/18    93 500         İnşaatçılar m.
#
#                    Date       Today
# 0   Bakı, 07 i̇yun 2022  06/14/2022
# 1   Bakı, 04 i̇yun 2022  06/14/2022
# 2     Bakı, dünən 15:48  06/14/2022
# 3     Bakı, dünən 15:16  06/14/2022
# 4     Bakı, 31 may 2022  06/14/2022
# 5   Bakı, 09 i̇yun 2022  06/14/2022
# 6     Bakı, dünən 14:47  06/14/2022
# 7   Bakı, 13 i̇yun 2022  06/14/2022
# 8     Bakı, bugün 01:26  06/14/2022
# 9     Bakı, bugün 00:53  06/14/2022
# 10    Bakı, bugün 00:30  06/14/2022
# 11    Bakı, bugün 00:24  06/14/2022
# 12    Bakı, bugün 00:00  06/14/2022
# 13    Bakı, dünən 23:57  06/14/2022
# 14    Bakı, dünən 23:48  06/14/2022
# 15    Bakı, dünən 23:46  06/14/2022
# 16    Bakı, dünən 23:41  06/14/2022
# 17    Bakı, dünən 23:41  06/14/2022
# 18    Bakı, dünən 23:33  06/14/2022
# 19    Bakı, dünən 23:28  06/14/2022
# 20    Bakı, dünən 23:19  06/14/2022
# 21    Bakı, dünən 23:18  06/14/2022
# 22    Bakı, dünən 22:59  06/14/2022
# 23    Bakı, dünən 22:58  06/14/2022
# 24    Bakı, dünən 22:56  06/14/2022
# 25    Bakı, dünən 22:44  06/14/2022
# 26    Bakı, dünən 22:33  06/14/2022
# 27    Bakı, dünən 22:23  06/14/2022
# 28    Bakı, dünən 22:19  06/14/2022
# 29    Bakı, dünən 22:16  06/14/2022
# 30    Bakı, dünən 22:01  06/14/2022
# 31    Bakı, dünən 21:59  06/14/2022

# %% [markdown]
# # for multipe pages

# %%
pip install lxml
pip install html5lib
import lxml
# Out:
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# Collecting lxml
#   Using cached lxml-4.9.0.tar.gz (3.4 MB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: lxml
#   Building wheel for lxml (setup.py) ... done
#   Created wheel for lxml: filename=lxml-4.9.0-cp36-cp36m-macosx_10_6_intel.whl size=3035456 sha256=e1265edf436e59df79104bb8ff4999b6f3780e928aaa8ac31ea3ad6688afbf74
#   Stored in directory: /Users/faridmammadaliyev/Library/Caches/pip/wheels/fe/c7/c1/7bd21552d62c16fe43842f719bd114ebe81f88ee818256519a
# Successfully built lxml
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# Installing collected packages: lxml
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# Successfully installed lxml-4.9.0
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -ipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution - (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
#page = 1
#titles = []
#while page != 35:
 #     url = f"https://www.bookdepository.com/bestsellers?page={page}"
  #    response = requests.get(url)
   #   html = response.content
    #  soup = bs(html, "lxml")
     # for h3 in soup.find_all("h3", class_="title"):
      #      titles.append(h3.get_text(strip=True))
      #page = page + 1

# %% [markdown]
# ## write a loop for multiple pages

# %%
page = 1
prices=[] #List to store name of the product
locations=[] #List to store price of the product
names=[] #List to store rating of the product
dates_posted=[] 

while page != 2000:
    
    url = f"https://bina.az/baki/alqi-satqi/menziller?page={page}"
    page_main = requests.get(url)
    soup = BeautifulSoup(page_main.content, "html.parser")

    results = soup.find(id="js-items-search")
    job_elements = results.find_all("div", class_="card_params")

    for job_element in job_elements:
        
        name = job_element.find("ul", class_="name")
        location = job_element.find(class_="location")
        price = job_element.find("span", class_="price-val")
        date_posted = job_element.find(class_="city_when")
    
        names.append(name.text)
        locations.append(location.text)
        prices.append(price.text)
        dates_posted.append(date_posted.text)
    
    page = page + 1

# %%
df = pd.DataFrame({'Name': names, 'Price':prices,'Location':locations, 'Date':dates_posted, 'Today': datetime.today().
                   strftime('%m/%d/%Y')})

# %%
df
# Out:
#                                 Name    Price               Location  \
# 0        2 otaqlı108 m²16/19 mərtəbə  138 000               Xətai r.
# 1          3 otaqlı103 m²5/9 mərtəbə  143 156         İnşaatçılar m.
# 2           2 otaqlı48 m²3/5 mərtəbə  110 000              Səbail r.
# 3      3 otaqlı108.1 m²12/13 mərtəbə  153 500           20 Yanvar m.
# 4                   4 otaqlı167.6 m²  251 400              28 May m.
# ...                              ...      ...                    ...
# 37595     2 otaqlı90 m²19/21 mərtəbə  110 000        Yeni Yasamal q.
# 37596     3 otaqlı163 m²9/17 mərtəbə  309 000  Elmlər Akademiyası m.
# 37597    2 otaqlı110 m²11/17 mərtəbə  180 000              Nəsimi r.
# 37598       4 otaqlı90 m²8/9 mərtəbə  168 000   Azadlıq Prospekti m.
# 37599    4 otaqlı185 m²10/16 mərtəbə  635 000   Şah İsmayıl Xətai m.
#
#                       Date       Today
# 0      Bakı, 03 i̇yun 2022  06/15/2022
# 1      Bakı, 12 i̇yun 2022  06/15/2022
# 2      Bakı, 13 i̇yun 2022  06/15/2022
# 3      Bakı, 12 i̇yun 2022  06/15/2022
# 4      Bakı, 10 i̇yun 2022  06/15/2022
# ...                    ...         ...
# 37595    Bakı, 18 may 2022  06/15/2022
# 37596    Bakı, 16 may 2022  06/15/2022
# 37597    Bakı, 12 may 2022  06/15/2022
# 37598  Bakı, 03 i̇yun 2022  06/15/2022
# 37599    Bakı, 10 may 2022  06/15/2022
#
# [37600 rows x 5 columns]

# %%
df['num_rooms'] = df['Name'].str.split('otaqlı', 1, expand=True)[0]

df['size'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[0]

df['floor'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[1].\
str.split('mərtəbə', 1, expand=True)[0]

# %%
df_1 = df[['num_rooms', 'size', 'floor', 'Price', 'Location', 'Date', 'Today']]

# %%
df_1
# Out:
#       num_rooms    size   floor    Price               Location  \
# 0            2     108   16/19   138 000               Xətai r.
# 1            3     103     5/9   143 156         İnşaatçılar m.
# 2            2      48     3/5   110 000              Səbail r.
# 3            3   108.1   12/13   153 500           20 Yanvar m.
# 4            4   167.6           251 400              28 May m.
# ...         ...     ...     ...      ...                    ...
# 37595        2      90   19/21   110 000        Yeni Yasamal q.
# 37596        3     163    9/17   309 000  Elmlər Akademiyası m.
# 37597        2     110   11/17   180 000              Nəsimi r.
# 37598        4      90     8/9   168 000   Azadlıq Prospekti m.
# 37599        4     185   10/16   635 000   Şah İsmayıl Xətai m.
#
#                       Date       Today
# 0      Bakı, 03 i̇yun 2022  06/15/2022
# 1      Bakı, 12 i̇yun 2022  06/15/2022
# 2      Bakı, 13 i̇yun 2022  06/15/2022
# 3      Bakı, 12 i̇yun 2022  06/15/2022
# 4      Bakı, 10 i̇yun 2022  06/15/2022
# ...                    ...         ...
# 37595    Bakı, 18 may 2022  06/15/2022
# 37596    Bakı, 16 may 2022  06/15/2022
# 37597    Bakı, 12 may 2022  06/15/2022
# 37598  Bakı, 03 i̇yun 2022  06/15/2022
# 37599    Bakı, 10 may 2022  06/15/2022
#
# [37600 rows x 7 columns]

# %%
df.to_csv('houses_baku.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('houses_baku.csv')

# %%
df['num_rooms'] = df['Name'].str.split('otaqlı', 1, expand=True)[0]

df['size'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[0]

df['floor'] = df['Name'].str.split('otaqlı', 1, expand=True)[1].str.split('m²', 1, expand=True)[1].\
str.split('mərtəbə', 1, expand=True)[0]

# %%
df_1 = df[['num_rooms', 'size', 'floor', 'Price', 'Location', 'Date', 'Today']]

# %%
df_1
# Out:
#       num_rooms    size   floor    Price               Location  \
# 0            2     108   16/19   138 000               Xətai r.
# 1            3     103     5/9   143 156         İnşaatçılar m.
# 2            2      48     3/5   110 000              Səbail r.
# 3            3   108.1   12/13   153 500           20 Yanvar m.
# 4            4   167.6           251 400              28 May m.
# ...         ...     ...     ...      ...                    ...
# 37595        2      90   19/21   110 000        Yeni Yasamal q.
# 37596        3     163    9/17   309 000  Elmlər Akademiyası m.
# 37597        2     110   11/17   180 000              Nəsimi r.
# 37598        4      90     8/9   168 000   Azadlıq Prospekti m.
# 37599        4     185   10/16   635 000   Şah İsmayıl Xətai m.
#
#                       Date       Today
# 0      Bakı, 03 i̇yun 2022  06/15/2022
# 1      Bakı, 12 i̇yun 2022  06/15/2022
# 2      Bakı, 13 i̇yun 2022  06/15/2022
# 3      Bakı, 12 i̇yun 2022  06/15/2022
# 4      Bakı, 10 i̇yun 2022  06/15/2022
# ...                    ...         ...
# 37595    Bakı, 18 may 2022  06/15/2022
# 37596    Bakı, 16 may 2022  06/15/2022
# 37597    Bakı, 12 may 2022  06/15/2022
# 37598  Bakı, 03 i̇yun 2022  06/15/2022
# 37599    Bakı, 10 may 2022  06/15/2022
#
# [37600 rows x 7 columns]

# %%
df_1.to_csv('houses_baku_parsered.csv', index=False, encoding='utf-8')

# %%
df_1
# Out:
#        num_rooms   size   floor    Price               Location  \
# 0              2  108.0  16/19   138 000               Xətai r.
# 1              3  103.0    5/9   143 156         İnşaatçılar m.
# 2              2   48.0    3/5   110 000              Səbail r.
# 3              3  108.1  12/13   153 500           20 Yanvar m.
# 4              4  167.6     NaN  251 400              28 May m.
# ...          ...    ...     ...      ...                    ...
# 37595          2   90.0  19/21   110 000        Yeni Yasamal q.
# 37596          3  163.0   9/17   309 000  Elmlər Akademiyası m.
# 37597          2  110.0  11/17   180 000              Nəsimi r.
# 37598          4   90.0    8/9   168 000   Azadlıq Prospekti m.
# 37599          4  185.0  10/16   635 000   Şah İsmayıl Xətai m.
#
#                       Date       Today
# 0      Bakı, 03 i̇yun 2022  06/15/2022
# 1      Bakı, 12 i̇yun 2022  06/15/2022
# 2      Bakı, 13 i̇yun 2022  06/15/2022
# 3      Bakı, 12 i̇yun 2022  06/15/2022
# 4      Bakı, 10 i̇yun 2022  06/15/2022
# ...                    ...         ...
# 37595    Bakı, 18 may 2022  06/15/2022
# 37596    Bakı, 16 may 2022  06/15/2022
# 37597    Bakı, 12 may 2022  06/15/2022
# 37598  Bakı, 03 i̇yun 2022  06/15/2022
# 37599    Bakı, 10 may 2022  06/15/2022
#
# [37600 rows x 7 columns]

# %%
df_1['Price'] = df_1['Price'].str.replace(' ', '').astype(int)

# %%
df_1.dtypes
# Out:
# num_rooms      int64
# size         float64
# floor         object
# Price          int64
# Location      object
# Date          object
# Today         object
# dtype: object

# %%
df_1['size'].describe()
# Out:
# count     37600.000000
# mean        114.175072
# std         852.950803
# min           3.000000
# 25%          69.000000
# 50%          97.000000
# 75%         135.000000
# max      165000.000000
# Name: size, dtype: float64

# %%
# Start the analysis

# %%
import matplotlib.pyplot as plt

plt.scatter(df_1[df_1['size'] < 150000]['Price'], df_1[df_1['size'] < 150000]['size'])
plt.show()

# %%
df_1[df_1['Price'] < 1000000]['Price'].hist()

# %%
df_1.describe()
# Out:
#           num_rooms           size         Price
# count  37600.000000   37600.000000  3.760000e+04
# mean       2.785691     114.175072  2.019396e+05
# std        1.051850     852.950803  1.887489e+05
# min        1.000000       3.000000  1.500000e+03
# 25%        2.000000      69.000000  1.100000e+05
# 50%        3.000000      97.000000  1.550000e+05
# 75%        3.000000     135.000000  2.399990e+05
# max       20.000000  165000.000000  5.000000e+06
